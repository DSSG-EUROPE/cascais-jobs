# %% [markdown]
# # Data set-up and cleaning

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import psycopg2 as pg
# %matplotlib inline
import seaborn as sns
import dbcreds

# %%
conn = pg.connect(dbname = dbcreds.database, host=dbcreds.host, user=dbcreds.user, password = dbcreds.password)

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
apps_df = pd.read_sql('select * from cascais_v2.application', con=conn)

# %%
# create datetime objects for date of application
from datetime import datetime, timedelta
apps_df.loc[:,'app_date']= apps_df.loc[:,'candidatura_data'].apply(
    lambda x: datetime(year=int(str(x)[0:4]), month=int(str(x)[5:7]),
                       day=int(str(x)[8:10])))

# create english education levels
eng_edu = {'11': '11', '12': '12', '04': '04', '06': '06', '09':'09',
          'BM': 'bachelor', 'DT': 'doctoral', 'PS': 'post-secondary',
          'SL': 'grade school', 'LC': 'licensed',
          'MT': 'masters', 'NS': 'cannot read/write'}
    
apps_df.loc[:, 'education'] = apps_df['chabilitacao_escolar'].map(eng_edu)

# create english categories
eng_category = {'DESEMPREGADO-NOVO EMPREGO': 'Unemployed - new job',
          'DESEMPREGADO-1Âº EMPREGO': 'Unemployed - first job',
          'EMPREGADO': 'Employed',
          'EMPREGADO A TEMPO PARCIAL':'Part-time employed'}
apps_df.loc[:, 'category'] = apps_df['dcategoria'].map(eng_category)

# create english nationality
eng_nat = {'PORTUGAL':'PORTUGAL','BRASIL': 'BRAZIL',
           'GUINÃ-BISSAU':'GUINEA-BISSAU','CABO VERDE': 'CAPE VERDE'}

apps_df.loc[:,'nationality'] = apps_df['dnacionalidade'].apply(
lambda x: eng_nat[x] if x in eng_nat.keys() else 'OTHER')

#convert dependents to integer
apps_df.loc[:,'all_dependents'] = apps_df.loc[:,'ute_nr_pessoas_cargo'].apply(lambda x: None if x is None else float(x))
apps_df.loc[:,'descendants'] = apps_df.loc[:,'ute_nr_descendentes_cargo'].apply(lambda x: None if x is None else float(x))

# %%
#create age buckets
def age_bucket(x):
    if x<30:
        return "<30"
    elif x<50:
        return "30-49"
    elif x<65:
        return "50-64"
    else:
        return "65+"

apps_df.loc[:, 'age_bucket'] = apps_df.loc[:, 'ute_idade'].apply(lambda x: age_bucket(x))

# %%
#create # of apps
app_counts = apps_df.ute_id.value_counts()
apps_df['app_count'] = apps_df['ute_id'].apply(lambda x: app_counts[x])

# %%
# filter for only unemployed
apps_unemp = apps_df[apps_df['dcategoria'].apply(lambda x: x[0:3]==('DES'))]
len(apps_unemp)
# Out:
# 119926

# %%
apps_unemp.columns
# Out:
# Index([u'anomes', u'ctipo_movimento', u'dtipo_movimento', u'ute_id', u'sexo',
#        u'chabilitacao_escolar', u'dhabilitacao_escolar', u'cdeficiencia',
#        u'ddeficiencia', u'cnacionalidade', u'dnacionalidade',
#        u'cnp_pretendida', u'dcnp_pretendida', u'cpp_pretendida',
#        u'dcpp_pretendida', u'candidatura_data', u'ccategoria', u'dcategoria',
#        u'candidatura_motivo_inscricao', u'candidatura_rinsc',
#        u'ute_estado_civil', u'candidatura_int_tempo_nao_insc',
#        u'candidatura_prof_pret_tempo_pratica',
#        u'sit_anterior_prof_tempo_pratica', u'candidatura_local_trabalho',
#        u'ute_plano_emprego', u'ute_plano_emprego_anterior',
#        u'candidatura_carteira_prof', u'candidatura_formacao_prof',
#        u'candidatura_qualificacao', u'reinscricao_ult_saida_data',
#        u'reinscricao_ult_saida_motivo', u'carea_formacao_tabela_em_activo',
#        u'darea_formacao_tabela_em_activo', u'carea_curso_tabela_em_activo',
#        u'darea_curso_tabela_em_activo', u'colocacao_regime_contrato',
#        u'colocacao_tipo_contrato', u'cnp_anterior', u'dcnp_anterior',
#        u'cpp_anterior', u'dcpp_anterior', u'dregime_contrato_pretendido',
#        u'sub_rsi', u'ute_curso_estabelec_ens_superior',
#        u'ute_curso_ano_conclusao', u'candidatura_origem', u'cae_anterior',
#        u'dcae_anterior', u'ute_data_nascimento', u'ute_idade',
#        u'conjuge_estado_civil', u'conjuge_categoria', u'conjuge_estado',
#        u'conjuge_motivo_indisponibilidade', u'candidatura_categoria_anterior',
#        u'candidatura_estado_anterior', u'ute_nr_pessoas_cargo',
#        u'ute_nr_descendentes_cargo', u'candidatura_data_ppe', u'table_index',
#        u'app_date', u'education', u'category', u'nationality',
#        u'all_dependents', u'descendants', u'age_bucket', u'app_count'],
#       dtype='object')

# %% [markdown]
# ## KY sanity checks

# %% [markdown]
# 10. Understand data cleaning needed for "transfer of center" cancellation reasons

# %%
move_df = pd.read_sql('select * from cascais_v2.movement', con=conn)

# %%
move_df[move_df['movement_type']=='application'].groupby(['ute_id', 'movement_index']).count().head()
# Out:
#                        movement_event_date  application_id  movement_type  \
# ute_id movement_index
# 710    120687                            1               1              1
# 818    70870                             1               1              1
# 820    22642                             1               1              1
#        61038                             1               1              1
# 832    1941                              1               1              1
#
#                        movement_subtype  movement_result
# ute_id movement_index
# 710    120687                         1                1
# 818    70870                          1                1
# 820    22642                          1                1
#        61038                          1                1
# 832    1941                           1                1

# %%
apps_df.groupby(['ute_id', 'table_index']).count().head()
# Out:
#                     anomes  ctipo_movimento  dtipo_movimento  sexo  \
# ute_id table_index
# 710    120687            1                1                1     1
# 818    70870             1                1                1     1
# 820    22642             1                1                1     1
#        61038             1                1                1     1
# 832    1941              1                1                1     1
#
#                     chabilitacao_escolar  dhabilitacao_escolar  cdeficiencia  \
# ute_id table_index
# 710    120687                          1                     1             1
# 818    70870                           1                     1             1
# 820    22642                           1                     1             1
#        61038                           1                     1             1
# 832    1941                            1                     1             1
#
#                     ddeficiencia  cnacionalidade  dnacionalidade    ...      \
# ute_id table_index                                                  ...
# 710    120687                  1               1               1    ...
# 818    70870                   1               1               1    ...
# 820    22642                   1               1               1    ...
#        61038                   1               1               1    ...
# 832    1941                    1               1               1    ...
#
#                     ute_nr_descendentes_cargo  candidatura_data_ppe  app_date  \
# ute_id table_index
# 710    120687                               1                     1         1
# 818    70870                                1                     0         1
# 820    22642                                0                     0         1
#        61038                                1                     0         1
# 832    1941                                 0                     0         1
#
#                     education  category  nationality  all_dependents  \
# ute_id table_index
# 710    120687               1         1            1               1
# 818    70870                1         1            1               1
# 820    22642                1         1            1               1
#        61038                1         1            1               1
# 832    1941                 1         1            1               1
#
#                     descendants  age_bucket  app_count
# ute_id table_index
# 710    120687                 1           1          1
# 818    70870                  1           1          1
# 820    22642                  0           1          1
#        61038                  1           1          1
# 832    1941                   0           1          1
#
# [5 rows x 67 columns]

# %%
merged = pd.merge(move_df, apps_df, how='inner', left_on='application_id', right_on='table_index')
#merged[['ute_id_x', 'ute_id_y']]
merged.loc[:, 'different']=merged['ute_id_x']!=merged['ute_id_y']

# %%
merged.different.sum()
# Out:
# 0

# %%
from utils import db_utils
from utils import iefp_data_utils

# %%
clean_apps = iefp_data_utils.clean_applications(apps_df,'1980-01-01','2016-04-30')
clean_movs2 = iefp_data_utils.clean_movements(move_df, '1980-01-01','2017-04-30',clean_apps['table_index'])

# %%
merged_clean = pd.merge(clean_movs2, clean_apps, how='inner', left_on='application_id', right_on='table_index')
merged_clean.loc[:, 'different']=merged['ute_id_x']!=merged['ute_id_y']

# %%
merged_clean.different.sum()
# Out:
# 0

# %%
#count blank movement event dates
#move_df[move_df['movement_event_date']==''].groupby('movement_type').count()

# %%
transfers = move_df[move_df['movement_subtype']=='TRANSFERÃNCIA DE CENTRO DE EMPREGO']

# %%
transfers.head()

# %%
plt.figure()
transfers.groupby('year').ute_id.count().plot(kind='bar')
plt.title("\nNumber of cancellations for Transfer de centro de emprego by year")

# %%
#look at specific users' paths
move_df[move_df['ute_id']==97213]

# %%
def next_move()

# %%
move_df.head()

# %% [markdown]
# ## Null analysis

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 1000)

def nulls_by_year(df):
    total_records = len(df)
    year_series = df.loc[:, 'anomes'].apply(lambda x: int(str(x)[0:4]))
    df_new = df.isnull().astype(int)
    df_new['year']=year_series
    
    df_new = df_new.groupby('year').sum()
    nulls_total = df_new.sum()
    nulls_total.name = 'nulls_total'
    
    return df_new.append(nulls_total).sort_values(by='nulls_total', ascending =False,axis=1).transpose().apply(lambda x: x/total_records*100)

nulls_by_year(apps_df)
# Out:
# year                                     2007      2008      2009      2010  \
# colocacao_tipo_contrato              7.707012  8.492430  9.888106  9.437810
# colocacao_regime_contrato            7.707012  8.492430  9.888106  9.437810
# conjuge_motivo_indisponibilidade     7.707012  8.492430  9.888106  9.437810
# conjuge_categoria                    7.707012  8.492430  9.888106  9.421014
# conjuge_estado                       7.707012  8.492430  9.888106  9.412216
# conjuge_estado_civil                 7.707012  8.492430  9.888106  8.863544
# darea_curso_tabela_em_activo         7.245519  7.237521  8.344464  7.928561
# carea_curso_tabela_em_activo         7.245519  7.237521  8.344464  7.928561
# ute_curso_estabelec_ens_superior     7.155140  7.210327  8.369258  7.943757
# ute_curso_ano_conclusao              7.153540  7.207128  8.363660  7.938958
# carea_formacao_tabela_em_activo      6.336130  7.135145  8.323669  7.914964
# darea_formacao_tabela_em_activo      6.336130  7.135145  8.323669  7.914964
# candidatura_carteira_prof            5.265178  5.996209  7.404682  7.229523
# dcpp_anterior                        7.707012  8.492430  9.888106  9.437810
# cpp_anterior                         7.707012  8.492430  9.888106  9.437810
# candidatura_formacao_prof            5.122012  5.812252  7.212727  7.040767
# candidatura_data_ppe                 7.707012  8.492430  9.888106  9.437810
# cpp_pretendida                       7.707012  8.492430  9.888106  9.437810
# dcpp_pretendida                      7.707012  8.492430  9.888106  9.437810
# candidatura_estado_anterior          7.707012  8.492430  9.888106  9.437810
# candidatura_categoria_anterior       7.707012  8.492430  9.888106  9.437810
# descendants                          7.707012  8.492430  9.888106  9.437810
# ute_nr_descendentes_cargo            7.707012  8.492430  9.888106  9.437810
# all_dependents                       3.264043  3.859105  3.933487  4.192627
# ute_nr_pessoas_cargo                 3.264043  3.859105  3.933487  4.192627
# ute_data_nascimento                  7.707012  8.492430  9.888106  9.437810
# candidatura_int_tempo_nao_insc       3.023299  3.256045  4.295004  3.877500
# reinscricao_ult_saida_data           2.992906  3.217654  4.267010  3.855106
# reinscricao_ult_saida_motivo         2.868135  3.181662  4.169433  3.812715
# candidatura_qualificacao             3.118477  3.455198  4.422174  4.322997
# dcnp_anterior                        0.746227  0.678243  0.789417  0.827808
# cnp_anterior                         0.746227  0.678243  0.789417  0.827808
# candidatura_local_trabalho           0.000000  0.000000  0.000000  0.000000
# cae_anterior                         0.746227  0.691040  1.466060  0.833407
# dcae_anterior                        0.746227  0.691040  1.466060  0.833407
# sit_anterior_prof_tempo_pratica      0.746227  0.678243  0.789417  0.827808
# cnp_pretendida                       0.000000  0.000000  0.000000  0.000000
# dcnp_pretendida                      0.000000  0.000000  0.000000  0.000000
# candidatura_prof_pret_tempo_pratica  1.575634  1.511649  1.650017  1.636420
# candidatura_origem                   6.617665  0.000000  0.001600  0.002399
# nationality                          0.000000  0.000000  0.000000  0.000000
# age_bucket                           0.000000  0.000000  0.000000  0.000000
# category                             0.000000  0.000000  0.000000  0.000000
# ute_idade                            0.000000  0.000000  0.000000  0.000000
# education                            0.000000  0.000000  0.000000  0.000000
# app_date                             0.000000  0.000000  0.000000  0.000000
# table_index                          0.000000  0.000000  0.000000  0.000000
# sub_rsi                              0.000000  0.000000  0.000000  0.000000
# dregime_contrato_pretendido          0.000000  0.000000  0.000000  0.000000
# ctipo_movimento                      0.000000  0.000000  0.000000  0.000000
# dtipo_movimento                      0.000000  0.000000  0.000000  0.000000
# ute_id                               0.000000  0.000000  0.000000  0.000000
# sexo                                 0.000000  0.000000  0.000000  0.000000
# chabilitacao_escolar                 0.000000  0.000000  0.000000  0.000000
# dhabilitacao_escolar                 0.000000  0.000000  0.000000  0.000000
# cdeficiencia                         0.000000  0.000000  0.000000  0.000000
# ddeficiencia                         0.000000  0.000000  0.000000  0.000000
# cnacionalidade                       0.000000  0.000000  0.000000  0.000000
# dnacionalidade                       0.000000  0.000000  0.000000  0.000000
# candidatura_data                     0.000000  0.000000  0.000000  0.000000
# ccategoria                           0.000000  0.000000  0.000000  0.000000
# dcategoria                           0.000000  0.000000  0.000000  0.000000
# candidatura_motivo_inscricao         0.000000  0.000000  0.000000  0.000000
# candidatura_rinsc                    0.000000  0.000000  0.000000  0.000000
# ute_estado_civil                     0.000000  0.000000  0.000000  0.000000
# ute_plano_emprego                    0.000000  0.000000  0.000000  0.000000
# ute_plano_emprego_anterior           0.000000  0.000000  0.000000  0.000000
# anomes                               0.000000  0.000000  0.000000  0.000000
# app_count                            0.000000  0.000000  0.000000  0.000000
#
# year                                     2011       2012       2013  \
# colocacao_tipo_contrato              9.405018  10.587944  10.507962
# colocacao_regime_contrato            9.405018  10.587944  10.507962
# conjuge_motivo_indisponibilidade     9.401819  10.587144  10.504763
# conjuge_categoria                    9.312240  10.465572  10.322405
# conjuge_estado                       9.279447  10.423982  10.257620
# conjuge_estado_civil                 9.036304  10.068064  9.909701
# darea_curso_tabela_em_activo         7.838981  8.542018   8.219693
# carea_curso_tabela_em_activo         7.838981  8.542018   8.219693
# ute_curso_estabelec_ens_superior     7.836582  8.553216   8.222092
# ute_curso_ano_conclusao              7.833383  8.553216   8.222092
# carea_formacao_tabela_em_activo      7.814187  8.530021   8.218893
# darea_formacao_tabela_em_activo      7.814187  8.530021   8.218893
# candidatura_carteira_prof            7.268714  8.302074   8.287677
# dcpp_anterior                        9.405018  10.587944  10.507962
# cpp_anterior                         9.405018  10.587944  10.507962
# candidatura_formacao_prof            7.057563  8.066928   8.097321
# candidatura_data_ppe                 9.405018  10.552752  4.235017
# cpp_pretendida                       9.405018  10.587944  10.507962
# dcpp_pretendida                      9.405018  10.587944  10.507962
# candidatura_estado_anterior          7.763799  3.659151   3.654352
# candidatura_categoria_anterior       7.476665  3.659151   3.653552
# descendants                          9.405018  3.898296   0.127970
# ute_nr_descendentes_cargo            9.405018  3.898296   0.127970
# all_dependents                       3.475994  4.422974   4.400579
# ute_nr_pessoas_cargo                 3.475994  4.422974   4.400579
# ute_data_nascimento                  5.135609  0.000000   0.000000
# candidatura_int_tempo_nao_insc       3.531981  4.083053   4.088651
# reinscricao_ult_saida_data           3.499188  4.060658   4.043862
# reinscricao_ult_saida_motivo         3.484792  3.961481   3.906294
# candidatura_qualificacao             4.867671  5.437938   0.214350
# dcnp_anterior                        0.722232  0.970975   1.291700
# cnp_anterior                         0.722232  0.970975   1.291700
# candidatura_local_trabalho           0.000000  0.033592   3.507986
# cae_anterior                         0.724632  0.974174   1.294100
# dcae_anterior                        0.724632  0.974174   1.294100
# sit_anterior_prof_tempo_pratica      0.722232  0.970975   1.291700
# cnp_pretendida                       0.000000  0.000000   0.000000
# dcnp_pretendida                      0.000000  0.000000   0.000000
# candidatura_prof_pret_tempo_pratica  1.350887  1.511649   0.015996
# candidatura_origem                   0.000800  0.000000   0.000000
# nationality                          0.000000  0.000000   0.000000
# age_bucket                           0.000000  0.000000   0.000000
# category                             0.000000  0.000000   0.000000
# ute_idade                            0.000000  0.000000   0.000000
# education                            0.000000  0.000000   0.000000
# app_date                             0.000000  0.000000   0.000000
# table_index                          0.000000  0.000000   0.000000
# sub_rsi                              0.000000  0.000000   0.000000
# dregime_contrato_pretendido          0.000000  0.000000   0.000000
# ctipo_movimento                      0.000000  0.000000   0.000000
# dtipo_movimento                      0.000000  0.000000   0.000000
# ute_id                               0.000000  0.000000   0.000000
# sexo                                 0.000000  0.000000   0.000000
# chabilitacao_escolar                 0.000000  0.000000   0.000000
# dhabilitacao_escolar                 0.000000  0.000000   0.000000
# cdeficiencia                         0.000000  0.000000   0.000000
# ddeficiencia                         0.000000  0.000000   0.000000
# cnacionalidade                       0.000000  0.000000   0.000000
# dnacionalidade                       0.000000  0.000000   0.000000
# candidatura_data                     0.000000  0.000000   0.000000
# ccategoria                           0.000000  0.000000   0.000000
# dcategoria                           0.000000  0.000000   0.000000
# candidatura_motivo_inscricao         0.000000  0.000000   0.000000
# candidatura_rinsc                    0.000000  0.000000   0.000000
# ute_estado_civil                     0.000000  0.000000   0.000000
# ute_plano_emprego                    0.000000  0.000000   0.000000
# ute_plano_emprego_anterior           0.000000  0.000000   0.000000
# anomes                               0.000000  0.000000   0.000000
# app_count                            0.000000  0.000000   0.000000
#
# year                                      2014       2015      2016      2017  \
# colocacao_tipo_contrato              10.433579  10.590343  9.814523  3.129674
# colocacao_regime_contrato            10.433579  10.590343  9.814523  3.129674
# conjuge_motivo_indisponibilidade     10.430380  10.592742  9.809724  3.128874
# conjuge_categoria                    10.266418  10.394389  9.655360  3.078486
# conjuge_estado                       10.164842  10.241624  9.515392  3.030497
# conjuge_estado_civil                 9.848915   9.940894   9.308240  2.970511
# darea_curso_tabela_em_activo         8.108519   8.261283   7.781395  2.481824
# carea_curso_tabela_em_activo         8.108519   8.261283   7.781395  2.481824
# ute_curso_estabelec_ens_superior     8.112518   8.262083   7.782994  2.484224
# ute_curso_ano_conclusao              8.113318   8.262083   7.782994  2.483424
# carea_formacao_tabela_em_activo      8.108519   8.260484   7.781395  2.481824
# darea_formacao_tabela_em_activo      8.108519   8.260484   7.781395  2.481824
# candidatura_carteira_prof            8.211695   8.414848   7.741404  2.507418
# dcpp_anterior                        6.335330   1.554839   1.302098  0.356717
# cpp_anterior                         6.335330   1.554839   1.302098  0.356717
# candidatura_formacao_prof            7.969351   8.150109   7.511057  2.415440
# candidatura_data_ppe                 3.507986   3.192059   2.745763  0.870998
# cpp_pretendida                       0.009598   0.018396   0.020795  0.003199
# dcpp_pretendida                      0.009598   0.018396   0.020795  0.003199
# candidatura_estado_anterior          3.212055   3.112078   2.705772  0.865399
# candidatura_categoria_anterior       3.211255   3.111278   2.705772  0.865399
# descendants                          0.071983   0.135968   0.200753  0.055187
# ute_nr_descendentes_cargo            0.071983   0.135968   0.200753  0.055187
# all_dependents                       4.398979   4.274208   3.880700  1.198922
# ute_nr_pessoas_cargo                 4.398979   4.274208   3.880700  1.198922
# ute_data_nascimento                  0.000000   0.000000   0.000000  0.000000
# candidatura_int_tempo_nao_insc       3.586368   3.376817   2.988907  0.944581
# reinscricao_ult_saida_data           3.471994   3.321629   2.900127  0.921386
# reinscricao_ult_saida_motivo         3.500788   3.439202   3.172064  1.036560
# candidatura_qualificacao             0.072783   0.026394   0.003999  0.003999
# dcnp_anterior                        3.459997   4.266210   4.203825  1.445265
# cnp_anterior                         3.459997   4.266210   4.203825  1.445265
# candidatura_local_trabalho           3.811916   4.220621   4.127043  1.401275
# cae_anterior                         1.565237   1.508450   1.283702  0.350319
# dcae_anterior                        1.565237   1.508450   1.283702  0.350319
# sit_anterior_prof_tempo_pratica      1.573235   1.502052   1.285302  0.352718
# cnp_pretendida                       2.517016   3.420806   3.515184  1.206120
# dcnp_pretendida                      2.517016   3.420806   3.515184  1.206120
# candidatura_prof_pret_tempo_pratica  0.006399   0.000800   0.000000  0.000800
# candidatura_origem                   0.000800   0.000000   0.000000  0.000000
# nationality                          0.000000   0.000000   0.000000  0.000000
# age_bucket                           0.000000   0.000000   0.000000  0.000000
# category                             0.000000   0.000000   0.000000  0.000000
# ute_idade                            0.000000   0.000000   0.000000  0.000000
# education                            0.000000   0.000000   0.000000  0.000000
# app_date                             0.000000   0.000000   0.000000  0.000000
# table_index                          0.000000   0.000000   0.000000  0.000000
# sub_rsi                              0.000000   0.000000   0.000000  0.000000
# dregime_contrato_pretendido          0.000000   0.000000   0.000000  0.000000
# ctipo_movimento                      0.000000   0.000000   0.000000  0.000000
# dtipo_movimento                      0.000000   0.000000   0.000000  0.000000
# ute_id                               0.000000   0.000000   0.000000  0.000000
# sexo                                 0.000000   0.000000   0.000000  0.000000
# chabilitacao_escolar                 0.000000   0.000000   0.000000  0.000000
# dhabilitacao_escolar                 0.000000   0.000000   0.000000  0.000000
# cdeficiencia                         0.000000   0.000000   0.000000  0.000000
# ddeficiencia                         0.000000   0.000000   0.000000  0.000000
# cnacionalidade                       0.000000   0.000000   0.000000  0.000000
# dnacionalidade                       0.000000   0.000000   0.000000  0.000000
# candidatura_data                     0.000000   0.000000   0.000000  0.000000
# ccategoria                           0.000000   0.000000   0.000000  0.000000
# dcategoria                           0.000000   0.000000   0.000000  0.000000
# candidatura_motivo_inscricao         0.000000   0.000000   0.000000  0.000000
# candidatura_rinsc                    0.000000   0.000000   0.000000  0.000000
# ute_estado_civil                     0.000000   0.000000   0.000000  0.000000
# ute_plano_emprego                    0.000000   0.000000   0.000000  0.000000
# ute_plano_emprego_anterior           0.000000   0.000000   0.000000  0.000000
# anomes                               0.000000   0.000000   0.000000  0.000000
# app_count                            0.000000   0.000000   0.000000  0.000000
#
# year                                 nulls_total
# colocacao_tipo_contrato              99.994401
# colocacao_regime_contrato            99.994401
# conjuge_motivo_indisponibilidade     99.980804
# conjuge_categoria                    99.003431
# conjuge_estado                       98.413168
# conjuge_estado_civil                 96.033720
# darea_curso_tabela_em_activo         81.989778
# carea_curso_tabela_em_activo         81.989778
# ute_curso_estabelec_ens_superior     81.932192
# ute_curso_ano_conclusao              81.913796
# carea_formacao_tabela_em_activo      80.905230
# darea_formacao_tabela_em_activo      80.905230
# candidatura_carteira_prof            76.629422
# dcpp_anterior                        75.575267
# cpp_anterior                         75.575267
# candidatura_formacao_prof            74.455526
# candidatura_data_ppe                 70.034952
# cpp_pretendida                       66.078270
# dcpp_pretendida                      66.078270
# candidatura_estado_anterior          60.497964
# candidatura_categoria_anterior       60.208432
# descendants                          49.420534
# ute_nr_descendentes_cargo            49.420534
# all_dependents                       41.301618
# ute_nr_pessoas_cargo                 41.301618
# ute_data_nascimento                  40.660967
# candidatura_int_tempo_nao_insc       37.052204
# reinscricao_ult_saida_data           36.551520
# reinscricao_ult_saida_motivo         36.533124
# candidatura_qualificacao             25.945981
# dcnp_anterior                        19.401899
# cnp_anterior                         19.401899
# candidatura_local_trabalho           17.102432
# cae_anterior                         11.437347
# dcae_anterior                        11.437347
# sit_anterior_prof_tempo_pratica      10.739908
# cnp_pretendida                       10.659127
# dcnp_pretendida                      10.659127
# candidatura_prof_pret_tempo_pratica  9.260252
# candidatura_origem                   6.623263
# nationality                          0.000000
# age_bucket                           0.000000
# category                             0.000000
# ute_idade                            0.000000
# education                            0.000000
# app_date                             0.000000
# table_index                          0.000000
# sub_rsi                              0.000000
# dregime_contrato_pretendido          0.000000
# ctipo_movimento                      0.000000
# dtipo_movimento                      0.000000
# ute_id                               0.000000
# sexo                                 0.000000
# chabilitacao_escolar                 0.000000
# dhabilitacao_escolar                 0.000000
# cdeficiencia                         0.000000
# ddeficiencia                         0.000000
# cnacionalidade                       0.000000
# dnacionalidade                       0.000000
# candidatura_data                     0.000000
# ccategoria                           0.000000
# dcategoria                           0.000000
# candidatura_motivo_inscricao         0.000000
# candidatura_rinsc                    0.000000
# ute_estado_civil                     0.000000
# ute_plano_emprego                    0.000000
# ute_plano_emprego_anterior           0.000000
# anomes                               0.000000
# app_count                            0.000000

# %% [markdown]
# ## Create histograms (all apps))

# %%
# plot number of apps by sex and category
status_order = ['Unemployed - new job', 'Unemployed - first job',
                'Part-time employed', 'Employed']

plt.figure()
sns.countplot(x='category', hue='sexo', data=apps_df, order=status_order)
plt.title("\n Number of applications by category and sex")
plt.xticks(rotation=45)

#plot dist of category by nationality
plt.figure()
sns.countplot(x='category', hue='nationality', data=apps_df, order=status_order)
plt.title("\nNumber of applications by category and nationality")
plt.xticks(rotation=45)

# plot number of times one applies (assumes sex and app count stays the same)
plt.figure()
first_app = apps_df.groupby('ute_id').first()
sns.countplot(x='app_count', hue='sexo', data=first_app)
plt.title("\n Number of users who applied X number of times between 2007-2017")
# Out:
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Create histograms (unemployed only)

# %%
#apps_unemp.columns
#apps_unemp.dnacionalidade.value_counts()

# %%
#plot dist of ages by sex
plt.figure()
plt.hist(apps_unemp[apps_unemp['sexo']=='M'].ute_idade, bins=np.arange(15,80,1), color='indianred',
        alpha=0.5)
plt.hist(apps_unemp[apps_unemp['sexo']=='F'].ute_idade, bins=np.arange(15,80,1), alpha =0.4)
plt.title("\nDistribution of unemployed applications by age and sexo")

#plot dist of ages by sex
plt.figure()
sns.countplot(x='age_bucket', hue='sexo', data=apps_unemp)
plt.title("\nDistribution of unemployed applications by age bucket and sexo")

# %%
edu_order = ['cannot read/write', 'grade school', 
            '04', '06', '09', '11', '12', 'post-secondary', 'licensed',
            'bachelor', 'masters', 'doctoral']
sns.countplot(x='education', hue='sexo', order=edu_order, data=apps_unemp)
plt.xticks(rotation=45)
plt.title("\nDistribution of applications by education and sexo (all ages)")

plt.figure()
sns.countplot(x='education', hue='sexo', order=edu_order,
              data=apps_unemp[apps_unemp['age_bucket']=="<30"])
plt.xticks(rotation=45)
plt.title("\nDistribution of applications by education and sexo (<30 y.o.)")

# %%
edu_age = DataFrame(apps_unemp.groupby(['education', 'age_bucket']).ute_id.count())
edu_age = edu_age.reset_index().pivot( "age_bucket", "education","ute_id")
edu_age = edu_age.reindex(index = ["65+", "50-64","30-49","<30"], columns = edu_order)
edu_age = edu_age.fillna(value = 0)

fig, ax = plt.subplots(figsize = (10,3))
sns.heatmap(edu_age, annot=True, fmt='g', ax=ax)
plt.title("\nNumber of applications by education and age")

# %%
plt.figure()
sns.countplot(x='sexo', hue='ute_estado_civil', data=apps_unemp)
plt.title("\nDistribution of applications by marital status and sexo")

plt.figure()
sns.countplot(x='age_bucket', hue='ute_estado_civil', data=apps_unemp)
plt.title("\nDistribution of applications by marital status and age")

# %%
plt.figure()
sns.barplot(x="ute_estado_civil", y="all_dependents", hue='sexo',
            data=apps_unemp)
plt.title("\nAverage number of dependents by sex and marital status")

plt.figure()
sns.regplot(x="all_dependents",y="descendants", data=apps_unemp)

# %%
des_dep = DataFrame(apps_unemp.groupby(['all_dependents', 'descendants']).ute_id.count())
des_dep = des_dep.reset_index().pivot( "all_dependents", "descendants","ute_id").sort_index(ascending=False)
#edu_age = edu_age.reindex(index = ["65+", "50-64","30-49","<30"], columns = edu_order)
#edu_age = edu_age.fillna(value = 0)

fig, ax = plt.subplots(figsize = (10,5))
sns.heatmap(des_dep, annot=True, fmt='g', ax=ax)
plt.title("\nNumber of dependents vs. Number of toal descendants")

# %% [markdown]
# ## Deep dive on young people (<30 y.o.)

# %%
events_df = pd.read_sql('select * from cascais.movement', con=conn)

# %%
events_df.columns
# Out:
# Index([u'ute_id', u'movement_date', u'year_month', u'application_id',
#        u'movement_type', u'movement_subtype', u'movement_result',
#        u'movement_index'],
#       dtype='object')

# %%
events_df.movement_index.sort_values(ascending=False)
# Out:
# 36315     256327
# 1802      256326
# 35395     256325
# 373       256324
# 34850     256323
# 34849     256322
# 34705     256321
# 366       256320
# 34083     256319
# 869987    256318
# 869980    256317
# 869975    256316
# 869973    256315
# 869965    256314
# 869963    256313
# 869960    256312
# 869958    256311
# 869955    256310
# 869954    256309
# 869948    256308
# 869934    256307
# 869932    256306
# 869930    256305
# 869924    256304
# 869912    256303
# 869910    256302
# 869907    256301
# 869902    256300
# 869899    256299
# 869896    256298
#            ...
# 38966          5
# 38360          5
# 53986          5
# 2581           5
# 37681          5
# 45037          5
# 38308          4
# 45036          4
# 38442          4
# 37664          4
# 51461          4
# 37295          4
# 0              3
# 50423          3
# 37296          3
# 43787          3
# 37172          3
# 38174          3
# 37171          2
# 45638          2
# 36812          2
# 42756          2
# 37536          2
# 37173          2
# 36936          1
# 2304           1
# 36521          1
# 36927          1
# 43963          1
# 37232          1
# Name: movement_index, Length: 870061, dtype: int64
