# %%
import pandas as pd
import numpy as np
import sys
from pandas import Series, DataFrame
from datetime import datetime
sys.path.append("../")
from utils import db_utils
from utils import iefp_data_utils
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(font_scale=1.5)

# %% [markdown]
# ## Connect to DB and read cascais data tables

# %%
conn = db_utils.connect_to_db()
#demo = db_utils.read_table(conn,'iefp','01_municipe')

# %%
# read from CSVs for now

municipe = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-01Municípe.csv')
atendimento = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-02Atendimento.csv')
gadi = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-03Gadi.csv')
virar = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-04Virar.csv')
pvp = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-05PVP.csv')
#mentoria = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-06Mentoria.csv')
mentor = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-07Mentor.csv')
epc = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-08EPC.csv')
oficinas = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-09Oficinas.csv')
acasos = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-10Acasos.csv')
poj = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-11POJ.csv')
escolaridade = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-12Escolaridade.csv')
situacaofacetrabalho = pd.read_csv('/mnt/data/shared/workingData/cascais/DPRE_updated-13Situaçãofacetrabalho.csv')

# %% [markdown]
# ## Clean / map data

# %%
municipe.Freguesia.value_counts()
# Out:
# Cascais Estoril               1016
# Sao Domingos de Rana           641
# Alcabideche                    641
# Carcavelos Parede              450
# Outra/o Freguesia/Concelho      33
# Concelho de Sintra              14
# Concelho de Lisboa               8
# Concelho de Oeiras               7
# Cascais                          1
# Mem Martins                      1
# Amoreira                         1
# Name: Freguesia, dtype: int64

# %%
#Make Sexo all lowercase
municipe['Sexo'] = municipe['Sexo'].apply(lambda x: None if pd.isnull(x) else x.lower())

#Map Freguesia to larger buckets
Freg_map = {'Cascais Estoril':'Cascais', 'Cascais': 'Cascais',\
           'Alcabideche':'Alcabideche', 'Amoreira':'Alcabideche',\
           'Sao Domingos de Rana':'Sao Domingos de Rana',
           'Carcavelos Parede': 'Carcavelos Parede',
           'Outra/o Freguesia/Concelho':'Other',\
           'Concelho de Sintra':'Other',\
           'Concelho de Lisboa':'Other',\
           'Mem Martins':'Other', 'Amoreira':'Other'}

municipe['region']=municipe['Freguesia'].map(Freg_map)

# %%
municipe.region.value_counts()
# Out:
# Cascais                 1017
# Sao Domingos de Rana     641
# Alcabideche              641
# Carcavelos Parede        450
# Other                     57
# Name: region, dtype: int64

# %%
#check that education and situation tabs have only 1 entry per id
print escolaridade.ID.value_counts().max()
print situacaofacetrabalho.ID.value_counts().max()
# Out:
# 1
# 1

# %%
# map education levels
Edu_map = {'12.º ano geral':'12','Licenciatura':'Licenciatura','09.º ano':"09", \
           "12.º ano tecnico-profissional":"12 tecnico-profissional","Mestrado":"Masters", "11.º ano":"12",\
           "Bacharelato": "Bachelors","10.º ano":"10", "06.º ano":"6", "Pos-graduacao":"Pos-graduacao",\
          "Curso de especializacao tecnologica":"Tech specialty course", "04.º ano":"4", }
escolaridade['education'] = escolaridade['UltimoDeEscolaridade'].map(Edu_map)

# 07.º ano                                 4
# 08.º ano                                 3
# 9ºano                                    3
# 12º ano                                  3
# Licenciatura Servico Social              1
# Estudante                                1
# Doutoramento                             1
# 02.º ano                                 1
# 9º ano                                   1

# %%
escolaridade.education.value_counts()
# Out:
# 12                         1242
# Licenciatura                675
# 09                          141
# 12 tecnico-profissional     116
# Masters                      74
# Bachelors                    24
# 6                            20
# 4                            20
# Tech specialty course        18
# Pos-graduacao                16
# 10                           16
# Name: education, dtype: int64

# %%
#map ID to education in municipality tab
edu_dict = dict(zip(escolaridade['ID'], escolaridade['education']))
municipe['education'] = municipe['ID'].astype(str).map(edu_dict)

# %%
#education ID error
escolaridade.ID.sort_values(ascending=False).head(20)
# Out:
# 2404    ; Estagio Profissional no Centro de Convivio n...
# 2403    ; Estagio Profissional na Policia Municipal de...
# 2457    ; Disciplina de Composicao (Secundario) na Esc...
# 2410             ; Curso de Salvamento e Desencarcerament
# 2422    ; \tCurso de Ciencias do Esporte – enfase em P...
# 2421       ; \tCurso Gestao de Futebol da IBMEC/RJ - 2012
# 2420    ; \tCurso Gestao Esportiva - Universidade Tric...
# 2419       : Simposio de Direito Esportivo da UFRJ - 2012
# 1970                                                 9999
# 1969                                                 9984
# 1968                                                 9974
# 1967                                                 9962
# 1966                                                 9705
# 1965                                                 9704
# 1964                                                 9703
# 1963                                                 9702
# 1962                                                 9701
# 1961                                                 9700
# 1960                                                 9699
# 1959                                                 9697
# Name: ID, dtype: object

# %%
#map ID to situation in municipality tab
situacao_dict = dict(zip(situacaofacetrabalho['ID'], situacaofacetrabalho['Situacao']))
municipe['situation'] = municipe['ID'].map(situacao_dict)

# %% [markdown]
# ## Filter data to include

# %%
#create datetime object for data insertion date

def create_datetime(df, date_column):
    df['insertion_date'] = pd.to_datetime(df[date_column])

df_list = [municipe, atendimento, gadi, virar, pvp, mentor, epc, oficinas, acasos, poj, escolaridade, situacaofacetrabalho]

date_column_list = ['Data de inserção de dados', 'Última data de atendimento', 'Última data de atendimento GADI',\
                   'Última data de atendimento VIRAR', 'Última data de acompanhamento PVP', 'Última data de atendimento Mentor',\
                   'Última data da sessão', 'Última data de atendimento Oficinas', 
                   'Última data de atendimentos ACASOS', 'Última data de atendimento POJ', 'Última data da Escolaridade',\
                   'Última data da Situação face ao trabalho']

#date_column_dict = dict(zip (df_list, date_column_list))
# for df in df_list:
#     create_datetime(df, date_column_list[df_list.index(df)])

# create_datetime(municipe, municipe.columns[1])
# create_datetime(atendimento, 'Última data de atendimento')
# create_datetime(gadi, 'Última data de atendimento GADI')
# create_datetime(virar, 'Última data de atendimento VIRAR')
# create_datetime(pvp, 'Última data de acompanhamento PVP')
# create_datetime(mentor, 'Última data de atendimento Mentor')
# create_datetime(epc, 'Última data da sessão')
# create_datetime(oficinas, 'Última data de atendimento Oficinas')
# create_datetime(acasos, 'Última data de atendimentos ACASOS')
# create_datetime(poj, 'Última data de atendimento POJ')
# create_datetime(escolaridade, 'Última data da Escolaridade')
# create_datetime(situacaofacetrabalho, 'Última data da Situação face ao trabalho')

create_datetime(municipe, 'Data de insercao de dados')
create_datetime(atendimento, 'Ultima data de atendimento')
create_datetime(gadi, 'Ultima data de atendimento GADI')
create_datetime(virar, 'Ultima data de atendimento VIRAR')
create_datetime(pvp, 'Ultima data de acompanhamento PVP')
create_datetime(mentor, 'Ultima data de atendimento Mentor')
create_datetime(epc, 'Ultima data da sessao')
create_datetime(oficinas, 'Ultima data de atendimento Oficinas')
create_datetime(acasos, 'Ultima data de atendimentos ACASOS')
create_datetime(poj, 'Ultima data de atendimento POJ')
create_datetime(escolaridade, 'Ultima data da Escolaridade')
create_datetime(situacaofacetrabalho, 'Ultima data da Situacao face ao trabalho')

# %%
for df in df_list:
    print df.columns
# Out:
# Index([u'ID', u'Data de insercao de dados', u'Data de nasscimento', u'Idade',
#        u'Sexo', u'Portador de deficiencia', u'deficiencia', u'Morada',
#        u'Localidade', u'CP', u'Freguesia', u'Nacionalidade', u'Naturalidade',
#        u'Possui carta de conducao',
#        u'Autoriza a utilizacao dos seus dados pessoais para divulgacao de outras iniciativas da DPRE',
#        u'Nao autoriza a utilizacao dos seus dados pessoais para divulgacao de outras iniciativas da DPRE',
#        u'region', u'education', u'situation', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de atendimento', u'Tipo de atendimento',
#        u'Informacao sobre A Dois', u'Informacao sobre EPC',
#        u'Informacao sobre GADI', u'Informacao sobre Oficinas',
#        u'Informacao sobre POJ', u'Informacao sobre PVP',
#        u'Informacao sobre Virar', u'Informacao sobre Outro',
#        u'Informacao sobre Outro - Qual', u'Inscricao em A Dois',
#        u'Inscricao em EPC', u'Inscricao em GADI', u'Inscricao em oficinas',
#        u'Inscricao em POJ', u'Inscricao em Virar', u'Inscricao em Outro',
#        u'Inscricao em Outro - Qual', u'Observacoes',
#        u'Encaminhado para Rota Jovem', u'Encaminhado para Centro de Emprego',
#        u'Encaminhado para CFR de Alcoitao',
#        u'Gabinete de emprego Gaivotas da Torre',
#        u'Gabinete de emprego SEA Adroana', u'Gabinete de emprego Cercica',
#        u'Gabinete de emprego JF do Estoril',
#        u'Gabinete de emprego Cruz Vermelha / Parede',
#        u'Gabinete de emprego CCP Carcavelos',
#        u'Gabinete de emprego Centro Cultural Moldavo',
#        u'Gabinete de emprego CESPA',
#        u'Gabinete de emprego DIIS Matocheironhos',
#        u'Gabinete de emprego DIIS Zambujal',
#        u'Gabinete de emprego Loja Cascais Jovem', u'Gabinete de emprego CQEP',
#        u'Servicos de apoio ao empreendedor SEA',
#        u'Servicos de apoio ao empreendedor DNA',
#        u'Servicos de apoio ao empreendedor CCP Carcavelos',
#        u'Servicos de apoio ao empreendedor AECC',
#        u'Servicos de apoio ao empreendedor Outros',
#        u'Servicos de apoio ao empreendedor Outros - Qual',
#        u'Tecnico/a de atendimento', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de atendimento GADI', u'Tecnico/a GADI',
#        u'Nº de minutos de acompanhamento', u'Conteudo Autoconhecimento',
#        u'Conteudo Locus controlo interno', u'Conteudo Instrumentos PAE',
#        u'Conteudo Ativacao de recursos externos', u'Conteudo Outros',
#        u'Conteudo Outros - Qual', u'Utilidade percebida', u'Registo da sessao',
#        u'Observacoes', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de atendimento VIRAR', u'Motivo da inscricao',
#        u'Data de entrada', u'Data de saida', u'Observacoes',
#        u'Motivo de saida Trabalho', u'Motivo de saida Formacao',
#        u'Motivo de saida Outro', u'Motivo de saida Outro - Qual',
#        u'Sessoes participadas', u'Utilidade percebida', u'Grupo',
#        u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de acompanhamento PVP', u'Data de entrada',
#        u'Data de termino', u'Servico enquadrador', u'Tecnico/a enquadrador/a',
#        u'Telefone', u'E-mail', u'Funcoes', u'Participou nas Oficinas',
#        u'Horas', u'Accoes realizadas', u'Fim do contrato CEI',
#        u'Fim do Subidio de Desemprego', u'Utilidade percebida',
#        u'Saida do programa', u'Em', u'Outro motivo',
#        u'Tecnico/a de acompanhamento', u'Conteudo Autoconhecimento',
#        u'Conteudo Locus controlo interno', u'Conteudo Instrumentos PAE',
#        u'Conteudo Ativacao de recursos externos', u'Conteudo Outro',
#        u'Conteudo Outro - Qual', u'Acompanhamento', u'Nº de horas',
#        u'Registo da sessao', u'Observacoes', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de atendimento Mentor',
#        u'Area(s) em que gostaria de ser mentor/a', u'Disponibilidade',
#        u'Motivacao', u'Participou em algum programa da CMC',
#        u'Conhecimento do programa', u'Certificado mentor entregue',
#        u'Certificado mentor entregue em',
#        u'Condicoes de participacao - Reside, trabalha ou estuda no concelho de Cascais',
#        u'Condicoes de participacao - Leu a descricao do projeto e compreende os objetivos',
#        u'Condicoes de participacao - Disponivel para contatos com os tecnicos/as do projeto',
#        u'Observacoes', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data da sessao', u'Local', u'Situacao',
#        u'Data de candidatura',
#        u'Medida de estagio a que se candidata - Medida Estagios Emprego',
#        u'Medida de estagio a que se candidata - Medida Reativar',
#        u'Idade entre os 18 e 3 anos, inclusive, com qualificacao igual ou superior ao 9º ano de escolaridade',
#        u'Idade superior a 3 anos, com qualificacao obtida ha menos de 3 anos',
#        u'Qualquer idade e nivel de qualificacao se se verificar uma das seguintes situacoes',
#        u'Referencia da vaga', u'Entidade empregadora', u'Registo oficial',
#        u'Funcao de estagio', u'Convocado/a para entrevista na DPRE',
#        u'Data da entrevista', u'Tecnico/a da DPRE', u'Selecionado/a',
#        u'Nao selecionado/a', u'Informado/a do desfecho do processo', u'Em',
#        u'Estagio Entidade empregadora', u'Nome oficial', u'Localidade',
#        u'Freguesia', u'Area de atividade', u'Tecnico/a DPRE', u'Grupo',
#        u'Data de inicio', u'Data de fim', u'Nivel de qualificacao',
#        u'Area de qualificacao', u'Funcao', u'Situacao do estagio', u'Medida',
#        u'Duracao', u'Observacoes', u'Utilidade percebida', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de atendimento Oficinas',
#        u'Oficina em que se inscreve', u'Outra - qual', u'Local da sessao',
#        u'Outro - qual', u'Motivo(s) da inscricao',
#        u'Sessoes / horas frequentadas', u'Faltou (com justificacao)',
#        u'Justificacao', u'Faltou (sem justificacao)',
#        u'Se o municipe faltou sem justificacao, so se podera inscrever novamente em',
#        u'Utilidade percebida', u'Observacoes', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de atendimentos ACASOS', u'Situacao', u'Local',
#        u'Edicao', u'Observacoes', u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data de atendimento POJ',
#        u'E a primeira vez que se inscreve', u'Codigo atual', u'Codigo antigo',
#        u'1º opcao', u'2º opcao', u'3º opcao', u'Motivo(s) da candidatura',
#        u'Motivo(s) relativo(s) ao(s) projeto(s) escolhido(s)',
#        ...
#        u'POJ - Observacoes',
#        u'Pos-POJ - Adequacao comunicacional e relacional',
#        u'Pos-POJ - Compromisso', u'Pos-POJ - Cumprimento de regras',
#        u'Pos-POJ - Motivacao', u'Pos-POJ - Responsabilidade',
#        u'Pos-POJ - Espaco para registo descritivo',
#        u'PPos-POJ - rojeto de vida ativa', u'Pos-POJ - Observacoes',
#        u'insertion_date'],
#       dtype='object', length=107)
# Index([u'ID', u'Ultima data da Escolaridade', u'UltimoDeEscolaridade',
#        u'Outra - Qual', u'A frequentar', u'Area', u'Observacoes', u'education',
#        u'insertion_date'],
#       dtype='object')
# Index([u'ID', u'Ultima data da Situacao face ao trabalho', u'Situacao',
#        u'Outra - qual', u'Observacoes', u'Inscrito/a no CE', u'Tempo',
#        u'insertion_date'],
#       dtype='object')

# %%
# identify IDs that were in 2016 or 2017, or was active in a program in 2016 or 2017
id_include = []
for df in df_list:
    id_include.extend(df[df['insertion_date']>pd.to_datetime('2016-01-01')].ID.tolist())

# get rid of duplicates
id_include = list(set(id_include))

# %%
#filter out from demographics table
print len(municipe)
print len(municipe[municipe['ID'].isin(id_include)])
municipe_clean = municipe[municipe['ID'].isin(id_include)]
# Out:
# 3437
# 1534

# %% [markdown]
# ## Cascais demographics histograms

# %%
#null analysis
plt.figure()
municipe_clean.isnull().mean().sort_values().plot(kind='barh')
plt.title('percent of variable that is null')
# Out:
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
DataFrame(municipe_clean.columns)
# Out:
#                                                     0
# 0                                                  ID
# 1                           Data de insercao de dados
# 2                                 Data de nasscimento
# 3                                               Idade
# 4                                                Sexo
# 5                             Portador de deficiencia
# 6                                         deficiencia
# 7                                              Morada
# 8                                          Localidade
# 9                                                  CP
# 10                                          Freguesia
# 11                                      Nacionalidade
# 12                                       Naturalidade
# 13                           Possui carta de conducao
# 14  Autoriza a utilizacao dos seus dados pessoais ...
# 15  Nao autoriza a utilizacao dos seus dados pesso...
# 16                                             region
# 17                                          education
# 18                                          situation
# 19                                     insertion_date

# %%
municipe_clean.education.value_counts()
# Out:
# 12                         452
# Licenciatura               418
# 09                         100
# 12 tecnico-profissional     99
# Masters                     49
# Bachelors                   23
# 10                          14
# 6                           13
# 4                           12
# Tech specialty course       11
# Pos-graduacao               11
# Name: education, dtype: int64

# %%
def simple_countplot(df, column):
    plt.figure(figsize=(10,5))
    #municipe_clean[column].hist()
    sns.countplot(x=column, data=df)
    plt.ylabel('number of users')
    plt.xticks(rotation=45)
    plt.show()

for column in ["Sexo", "region", "Nacionalidade",\
               "education", "situation"]:
   simple_countplot(municipe_clean, column)

# age_plot = sns.countplot(x='Idade', data=municipe_clean)
# for label in age_plot.axis.get_ticklabels()[::5]:
#     label.set_visible(False)

# %%
# plot histogram of age by sex
fig = plt.figure()
ax = fig.add_subplot()
plt.title('Histogram of age by sex')
plt.xlabel('Age buckets')
plt.ylabel('Percent of applications')
municipe_clean[municipe_clean['Sexo']=='feminino'].Idade.hist(ax=ax, bins = 11, range = [15,70], normed=True, color='green', alpha=1.0)
municipe_clean[municipe_clean['Sexo']=='masculino'].Idade.hist(ax=ax, bins = 11, range = [15,70], normed=True, color='blue', alpha=0.5)
plt.legend()
# Out:
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# plot histogram of age
fig = plt.figure()
ax = fig.add_subplot()
plt.title('Histogram of age')
plt.xlabel('Age buckets')
plt.ylabel('Percent of applications')
municipe_clean.Idade.hist(ax=ax, bins = 30, normed=True, color='red', alpha=1.0)

# %%
# # histogram of male age for each region

# def age_hist(df, sex, region):
#     fig = plt.figure()
#     ax = fig.add_subplot()
#     plt.title(str(sex)+' age histogram for '+str(region))
#     plt.xlabel('Age buckets')
#     plt.ylabel('Percent of applications')
#     df[(df['region']==region) &\
#                   (df['Sexo']==sex)].Idade.hist(ax=ax, bins = 11, range = [15,70], normed=True, color='red', alpha=1.0)
#     df.Idade.hist(ax=ax, bins = 11, range = [15,70], normed=True, color='blue', alpha=0.5)
#     plt.show()

# for region in municipe_clean.region:
#     for sex in municipe_clean.Sexo:
#         age_hist(municipe_clean, sex, region)

# %%
#gender breakdown by region
plt.figure()
municipe_clean.groupby('region').Sexo.value_counts(normalize=True).unstack().plot(kind='bar', stacked=True, \
                                                                                  color=['green', 'blue'], legend=False)
plt.xticks(rotation=45)
plt.ylabel('Percent of users')

# %% [markdown]
# ## Histograms using education and situation tables

# %%
escolaridade_clean = escolaridade[escolaridade['ID'].isin(id_include)]
situacao_clean = situacaofacetrabalho[situacaofacetrabalho['ID'].isin(id_include)]

# %%
simple_countplot(escolaridade_clean, 'UltimoDeEscolaridade')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-26-4a7b9fd0ecf5> in <module>()
# ----> 1 simple_countplot(escolaridade_clean, 'UltimoDeEscolaridade')
#
# <ipython-input-20-6635e4702ab8> in simple_countplot(df, column)
#       2     plt.figure(figsize=(10,5))
#       3     #municipe_clean[column].hist()
# ----> 4     sns.countplot(x=column, data=df)
#       5     plt.ylabel('number of users')
#       6     plt.xticks(rotation=45)
#
# /opt/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, ax, **kwargs)
#    3263         ax = plt.gca()
#    3264
# -> 3265     plotter.plot(ax, kwargs)
#    3266     return ax
#    3267
#
# /opt/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in plot(self, ax, bar_kws)
#    1594         """Make the plot."""
#    1595         self.draw_bars(ax, bar_kws)
# -> 1596         self.annotate_axes(ax)
#    1597         if self.orient == "h":
#    1598             ax.invert_yaxis()
#
# /opt/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in annotate_axes(self, ax)
#     382         if self.orient == "v":
#     383             ax.set_xticks(np.arange(len(self.plot_data)))
# --> 384             ax.set_xticklabels(self.group_names)
#     385         else:
#     386             ax.set_yticks(np.arange(len(self.plot_data)))
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_xticklabels(self, labels, fontdict, minor, **kwargs)
#    3037             kwargs.update(fontdict)
#    3038         ret = self.xaxis.set_ticklabels(labels,
# -> 3039                                         minor=minor, **kwargs)
#    3040         self.stale = True
#    3041         return ret
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in set_ticklabels(self, ticklabels, *args, **kwargs)
#    1601         for tick_label, tick in zip(ticklabels, ticks):
#    1602             # deal with label1
# -> 1603             tick.label1.set_text(tick_label)
#    1604             tick.label1.update(kwargs)
#    1605             # deal with label2
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc2 in position 3: ordinal not in range(128)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /opt/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/anaconda/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2198                     orientation=orientation,
#    2199                     dryrun=True,
# -> 2200                     **kwargs)
#    2201                 renderer = self.figure._cachedRenderer
#    2202                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1134         renderer.open_group(__name__)
#    1135
# -> 1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1138                                                                 renderer)
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _update_ticks(self, renderer)
#    1059                 continue
#    1060             tick.update_position(loc)
# -> 1061             tick.set_label1(label)
#    1062             tick.set_label2(label)
#    1063             ticks_to_draw.append(tick)
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in set_label1(self, s)
#     275         ACCEPTS: str
#     276         """
# --> 277         self.label1.set_text(s)
#     278         self.stale = True
#     279
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc2 in position 3: ordinal not in range(128)

# %%
situacao_clean.Situacao.value_counts()

# %%
#gender breakdown by education level
edu_order = ['4', '6', '09', '10', '12', '12 tecnico-profissional', 'Tech specialty course', 'Licenciatura', 
            'Bachelors', 'Masters', 'Pos-graduacao']


plt.figure(figsize = (10,5))
sns.countplot(x='education', hue='Sexo', order=edu_order, data=municipe_clean)
# municipe_clean.groupby('education').Sexo.value_counts(normalize=True).unstack().plot(kind='bar', stacked=True, \
#                                                                                   color=['green', 'blue'], legend=False,\
#                                                                                     order=edu_order)
plt.xticks(rotation=45)
plt.ylabel('Number of users')

# %%
#Situation
municipe.situation.value_counts().sort_values(ascending=True).plot(kind='barh')
plt.xlabel('Number of users')
