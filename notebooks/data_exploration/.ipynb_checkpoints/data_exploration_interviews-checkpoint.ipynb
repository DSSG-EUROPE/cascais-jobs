ECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 20      RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 21      RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 22      RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 23                                                  OUTRO
# 24      RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 25      RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 26      RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 27             RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 28                                     O CANDIDATO FALTOU
# 29                       NÃO RESPOSTA APÃS INSISTÃNCIA
# ...                                                   ...
# 127672  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127673  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127674  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127675  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127676  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127677  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127678  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127679  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127680  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127681  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127682  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127683  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127684  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 127685  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127686  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127687            RECUSA CANDIDATO - PROFISSÃO OFERECIDA
# 127688  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127689  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127690  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127691  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 127692  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127693                                 O CANDIDATO FALTOU
# 127694  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 127695  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 127696  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127697  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 127698  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127699  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# 127700                                 O CANDIDATO FALTOU
# 127701  RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
#
# [127702 rows x 6 columns]

# %%
type(results_df)
# Out:
# pandas.core.frame.DataFrame

# %%
results_df.head()
# Out:
#    anomes  ctipo_movimento            dtipo_movimento   ute_id  \
# 0  200701               37  RESULTADO APRESENTAÃÃES  1060922
# 1  200701               37  RESULTADO APRESENTAÃÃES  1062047
# 2  200701               37  RESULTADO APRESENTAÃÃES  1062047
# 3  200701               37  RESULTADO APRESENTAÃÃES  1080395
# 4  200701               37  RESULTADO APRESENTAÃÃES  1133828
#
#    apresentacao_resultado                            dresultado_apresentacao
# 0                      22  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 1                      10                                ADMITIDO / COLOCADO
# 2                      29         RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 3                      10                                ADMITIDO / COLOCADO
# 4                      21  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...

# %%
dir(results_df) #can also hit tab after results_df.
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_only_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_apply_broadcast',
#  '_apply_empty_result',
#  '_apply_raw',
#  '_apply_standard',
#  '_at',
#  '_box_col_values',
#  '_box_item_values',
#  '_builtin_table',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_percentile',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_scalar',
#  '_combine_const',
#  '_combine_frame',
#  '_combine_match_columns',
#  '_combine_match_index',
#  '_combine_series',
#  '_combine_series_infer',
#  '_compare_frame',
#  '_compare_frame_evaluate',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_for_slice',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_create_indexer',
#  '_cython_table',
#  '_dir_additions',
#  '_dir_deletions',
#  '_ensure_valid_index',
#  '_expand_axes',
#  '_flex_compare_frame',
#  '_from_arrays',
#  '_from_axes',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_numeric_data',
#  '_get_values',
#  '_getitem_array',
#  '_getitem_column',
#  '_getitem_frame',
#  '_getitem_multilevel',
#  '_getitem_slice',
#  '_gotitem',
#  '_iat',
#  '_iget_item_cache',
#  '_iloc',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_dict',
#  '_init_mgr',
#  '_init_ndarray',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_cython_func',
#  '_is_datelike_mixed_type',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_loc',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_axis',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_setup_axes',
#  '_shallow_copy',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_unpickle_frame_compat',
#  '_unpickle_matrix_compat',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'anomes',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'apresentacao_resultado',
#  'as_blocks',
#  'as_matrix',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'axes',
#  'between_time',
#  'bfill',
#  'blocks',
#  'bool',
#  'boxplot',
#  'clip',
#  'clip_lower',
#  'clip_upper',
#  'columns',
#  'combine',
#  'combine_first',
#  'compound',
#  'consolidate',
#  'convert_objects',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'ctipo_movimento',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'dresultado_apresentacao',
#  'drop',
#  'drop_duplicates',
#  'dropna',
#  'dtipo_movimento',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'from_csv',
#  'from_dict',
#  'from_items',
#  'from_records',
#  'ftypes',
#  'ge',
#  'get',
#  'get_dtype_counts',
#  'get_ftype_counts',
#  'get_value',
#  'get_values',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'info',
#  'insert',
#  'interpolate',
#  'is_copy',
#  'isin',
#  'isnull',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'ix',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_axis',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'set_value',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'sortlevel',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dense',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_msgpack',
#  'to_panel',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sparse',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'ute_id',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
results_df.shape
# Out:
# (127702, 6)

# %%
results_df[['anomes','ute_id']][0:5] # first 5 rows of the two specified columns
# Out:
#    anomes   ute_id
# 0  200701  1060922
# 1  200701  1062047
# 2  200701  1062047
# 3  200701  1080395
# 4  200701  1133828

# %%
interviews = results_df.drop(['ctipo_movimento'], axis =1)

# %%
interviews.describe(include=['O'])
# Out:
#                   dtipo_movimento  \
# count                      127702
# unique                          1
# top     RESULTADO APRESENTAÃÃES
# freq                       127702
#
#                                   dresultado_apresentacao
# count                                              127702
# unique                                                 22
# top     RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃ...
# freq                                                33489

# %%
interviews['dresultado_apresentacao'].value_counts()
# Out:
# RECUSA DA ENTIDADE EMPREGADORA - NÃO MARCAÃÃO DA ENTREVISTA DA E.E. APÃS 1Âº CONTACTO    33489
# RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENTO PROFISSIONAL                                 29496
# RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PREENCHIDO                                        22349
# NÃO RESPOSTA APÃS INSISTÃNCIA                                                             11586
# ADMITIDO / COLOCADO                                                                           7738
# APRESENTAÃÃO SEM EFEITO                                                                     7090
# RECUSA DA ENTIDADE EMPREGADORA - PRETERIDO EM FUNÃÃO DO COLOCADO                            5917
# RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS                                                    3748
# O CANDIDATO FALTOU                                                                            2459
# RECUSA DA ENTIDADE EMPREGADORA - VALORAÃÃO SUBJECTIVA DA E.E.                                867
# CESSAÃÃO DA NECESSIDADE DE ADMISSÃO                                                         840
# RECUSA DO CANDIDATO - OUTRAS RAZÃES                                                           599
# OUTRO                                                                                          557
# RECUSA CANDIDATO - PROFISSÃO OFERECIDA                                                        455
# ANULADO - INDISPONIBILIDADE POR BAIXA MÃDICA                                                  141
# RECUSA DO CANDIDATO - RAZÃES SALARIAIS                                                        107
# RECUSA DO CANDIDATO - DISTÃNCIA/TEMPO                                                         105
# RECUSA DA ENTIDADE EMPREGADORA - FACTOS DECLARADOS PELO CANDIDATO                               52
# COLOCAÃÃO NO ÃMBITO DE OUTRA APRESENTAÃÃO                                                  38
# BAIXA MÃDICA                                                                                   25
# RECUSA DO CANDIDATO - MÃS CONDIÃÃES TRABALHO                                                 23
# RECUSA DO CANDIDATO - DESPESAS DE DESLOCAÃÃO                                                  21
# Name: dresultado_apresentacao, dtype: int64

# %%
interviews['dresultado_apresentacao'].value_counts().plot(kind='bar')

# %%
interviews[interviews['anomes'] == 200801]
# Out:
#        anomes            dtipo_movimento   ute_id  apresentacao_resultado  \
# 15013  200801  RESULTADO APRESENTAÃÃES   104242                      21
# 15014  200801  RESULTADO APRESENTAÃÃES  1060922                      22
# 15015  200801  RESULTADO APRESENTAÃÃES  1060922                      29
# 15016  200801  RESULTADO APRESENTAÃÃES   110733                      21
# 15017  200801  RESULTADO APRESENTAÃÃES  1105228                      50
# 15018  200801  RESULTADO APRESENTAÃÃES  1156748                      22
# 15019  200801  RESULTADO APRESENTAÃÃES  1161730                      21
# 15020  200801  RESULTADO APRESENTAÃÃES  1161730                      22
# 15021  200801  RESULTADO APRESENTAÃÃES  1161730                      50
# 15022  200801  RESULTADO APRESENTAÃÃES    12716                      22
# 15023  200801  RESULTADO APRESENTAÃÃES    12755                      22
# 15024  200801  RESULTADO APRESENTAÃÃES   131999                      22
# 15025  200801  RESULTADO APRESENTAÃÃES   132316                      21
# 15026  200801  RESULTADO APRESENTAÃÃES   132316                      22
RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 15014  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15015         RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 15016  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 15017                   NÃO RESPOSTA APÃS INSISTÃNCIA
# 15018  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15019  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 15020  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15021                   NÃO RESPOSTA APÃS INSISTÃNCIA
# 15022  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15023  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15024  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15025  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 15026  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15027  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15028  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15029  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 15030  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 15032  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15033         RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 15034                                              OUTRO
# 15035  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15036  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 15037  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15038  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15039  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 15040                                 O CANDIDATO FALTOU
# 15041                   NÃO RESPOSTA APÃS INSISTÃNCIA
# 15042                                ADMITIDO / COLOCADO
# 15043  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# ...                                                  ...
# 16336                                ADMITIDO / COLOCADO
# 16337  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16338  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16339  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16340  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16341         RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 16342  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16343  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16344  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16345  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16346  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16347  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16348  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16349  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16350                                 O CANDIDATO FALTOU
# 16351  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16352  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16353         RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 16354                                 O CANDIDATO FALTOU
# 16355                   NÃO RESPOSTA APÃS INSISTÃNCIA
# 16356  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16357         RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 16358  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16359  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16360  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16361  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16362  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 16363  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16364  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
# 16365                   NÃO RESPOSTA APÃS INSISTÃNCIA
#
# [1345 rows x 5 columns]

# %%
interviews['year']= interviews['anomes'].apply(lambda x: int(str(x)[:4]))
interviews['month']= interviews['anomes'].apply(lambda x: int(str(x)[4:6]))

# %%
interviews.dtypes
# Out:
# anomes                      int64
# dtipo_movimento            object
# ute_id                      int64
# apresentacao_resultado      int64
# dresultado_apresentacao    object
# year                        int64
# dtype: object

# %%
interviews.year.value_counts()
# Out:
# 2010    17427
# 2009    15063
# 2007    14987
# 2008    12924
# 2015    12319
# 2011    12015
# 2016    11145
# 2012    10279
# 2014     9793
# 2013     7948
# 2017     3802
# Name: year, dtype: int64

# %%
interviews[interviews['year']==2016].groupby(['dresultado_apresentacao']).ute_id.agg(['count']).plot(kind='bar')

# %%
interviews.groupby(['year','dresultado_apresentacao']).ute_id.agg(['count']).unstack('year').plot()

# %%
sns.distplot('dresultado_apresentacao', kde=False, rug=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ab0a8ef67664> in <module>()
# ----> 1 sns.distplot('dresultado_apresentacao', kde=False, rug=True)
#
# /opt/anaconda/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     190             line, = ax.plot(0, a.mean())
#     191         else:
# --> 192             line, = ax.plot(a.mean(), 0)
#     193         color = line.get_color()
#     194         line.remove()
#
# /opt/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type
