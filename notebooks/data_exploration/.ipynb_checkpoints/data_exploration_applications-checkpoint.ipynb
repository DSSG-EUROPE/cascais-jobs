# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import psycopg2 as pg
# %matplotlib inline

# %%
conn = pg.connect(dbname = "postgres", host="db.dssg.io", user='kyang', password = 'postgresis19')

# %%
script = "select * from IEFP.applications;"

# %%
results_df = pd.read_sql(script, con=conn)

# %%
results_df.head()
# Out:
#    anomes  ctipo_movimento                     dtipo_movimento   ute_id sexo  \
# 0  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1058797    M
# 1  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1062047    F
# 2  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1080395    F
# 3  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1194683    F
# 4  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1199775    M
#
#   chabilitacao_escolar dhabilitacao_escolar  cdeficiencia  \
# 0                    9               9 ANOS             0
# 1                    6               6 ANOS             0
# 2                    6               6 ANOS            21
# 3                   LC         LICENCIATURA             0
# 4                    9               9 ANOS             0
#
#               ddeficiencia cnacionalidade         ...          ute_idade  \
# 0           NÃO DEFICIENTE             PT         ...                 29
# 1           NÃO DEFICIENTE             PT         ...                 46
# 2  DEFICIÊNCIAS DA MEMÓRIA             PT         ...                 31
# 3           NÃO DEFICIENTE             PT         ...                 34
# 4           NÃO DEFICIENTE             PT         ...                 26
#
#    conjuge_estado_civil conjuge_categoria  conjuge_estado  \
# 0                  None               NaN            None
# 1                  None               NaN            None
# 2                  None               NaN            None
# 3                  None               NaN            None
# 4                  None               NaN            None
#
#   conjuge_motivo_indisponibilidade candidatura_categoria_anterior  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    candidatura_estado_anterior ute_nr_pessoas_cargo  \
# 0                         None                  0.0
# 1                         None                  1.0
# 2                         None                  1.0
# 3                         None                  0.0
# 4                         None                  0.0
#
#    ute_nr_descendentes_cargo candidatura_data_ppe
# 0                        NaN                 None
# 1                        NaN                 None
# 2                        NaN                 None
# 3                        NaN                 None
# 4                        NaN                 None
#
# [5 rows x 60 columns]

# %%
type(results_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# results_df.rename(columns={'anomes':'yearmonth'})

# %%
results_df.head()
# Out:
#    anomes  ctipo_movimento                     dtipo_movimento   ute_id sexo  \
# 0  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1058797    M
# 1  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1062047    F
# 2  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1080395    F
# 3  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1194683    F
# 4  200701               11  PEDIDOS DE EMPREGO AO LONGO DO MÊS  1199775    M
#
#   chabilitacao_escolar dhabilitacao_escolar  cdeficiencia  \
# 0                    9               9 ANOS             0
# 1                    6               6 ANOS             0
# 2                    6               6 ANOS            21
# 3                   LC         LICENCIATURA             0
# 4                    9               9 ANOS             0
#
#               ddeficiencia cnacionalidade         ...          ute_idade  \
# 0           NÃO DEFICIENTE             PT         ...                 29
# 1           NÃO DEFICIENTE             PT         ...                 46
# 2  DEFICIÊNCIAS DA MEMÓRIA             PT         ...                 31
# 3           NÃO DEFICIENTE             PT         ...                 34
# 4           NÃO DEFICIENTE             PT         ...                 26
#
#    conjuge_estado_civil conjuge_categoria  conjuge_estado  \
# 0                  None               NaN            None
# 1                  None               NaN            None
# 2                  None               NaN            None
# 3                  None               NaN            None
# 4                  None               NaN            None
#
#   conjuge_motivo_indisponibilidade candidatura_categoria_anterior  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    candidatura_estado_anterior ute_nr_pessoas_cargo  \
# 0                         None                  0.0
# 1                         None                  1.0
# 2                         None                  1.0
# 3                         None                  0.0
# 4                         None                  0.0
#
#    ute_nr_descendentes_cargo candidatura_data_ppe
# 0                        NaN                 None
# 1                        NaN                 None
# 2                        NaN                 None
# 3                        NaN                 None
# 4                        NaN                 None
#
# [5 rows x 60 columns]

# %%
user_counts = results_df.ute_id.value_counts()
user_counts.head()
# Out:
# 2334945    35
# 5745193    30
# 2981696    20
# 3672353    18
# 2433439    17
# Name: ute_id, dtype: int64

# %%
user_counts.value_counts().sort_index()
# Out:
# 1     36213
# 2     14833
# 3      6954
# 4      3716
# 5      1800
# 6       935
# 7       498
# 8       264
# 9       130
# 10       91
# 11       37
# 12       17
# 13       21
# 14        3
# 15        6
# 17        1
# 18        1
# 20        1
# 30        1
# 35        1
# Name: ute_id, dtype: int64

# %%
results_df['user_count'] = results_df['ute_id'].apply(lambda x: user_counts[x])

# %%
#results_df.groupby(['candidatura_rinsc', 'user_count']).ute_id.agg(['count']) #does not take into account the fact that one user ID could be both

# %%
results_df.columns
# Out:
# Index([u'anomes', u'ctipo_movimento', u'dtipo_movimento', u'ute_id', u'sexo',
#        u'chabilitacao_escolar', u'dhabilitacao_escolar', u'cdeficiencia',
#        u'ddeficiencia', u'cnacionalidade', u'dnacionalidade',
#        u'cnp_pretendida', u'dcnp_pretendida', u'cpp_pretendida',
#        u'dcpp_pretendida', u'candidatura_data', u'ccategoria', u'dcategoria',
#        u'candidatura_motivo_inscricao', u'candidatura_rinsc',
#        u'ute_estado_civil', u'candidatura_int_tempo_nao_insc',
#        u'candidatura_prof_pret_tempo_pratica',
#        u'sit_anterior_prof_tempo_pratica', u'candidatura_local_trabalho',
#        u'ute_plano_emprego', u'ute_plano_emprego_anterior',
#        u'candidatura_carteira_prof', u'candidatura_formacao_prof',
#        u'candidatura_qualificacao', u'reinscricao_ult_saida_data',
#        u'reinscricao_ult_saida_motivo', u'carea_formacao_tabela_em_activo',
#        u'darea_formacao_tabela_em_activo', u'carea_curso_tabela_em_activo',
#        u'darea_curso_tabela_em_activo', u'colocacao_regime_contrato',
#        u'colocacao_tipo_contrato', u'cnp_anterior', u'dcnp_anterior',
#        u'cpp_anterior', u'dcpp_anterior', u'dregime_contrato_pretendido',
#        u'sub_rsi', u'ute_curso_estabelec_ens_superior',
#        u'ute_curso_ano_conclusão', u'candidatura_origem', u'cae_anterior',
#        u'dcae_anterior', u'ute_data_nascimento', u'ute_idade',
#        u'conjuge_estado_civil', u'conjuge_categoria', u'conjuge_estado',
#        u'conjuge_motivo_indisponibilidade', u'candidatura_categoria_anterior',
#        u'candidatura_estado_anterior', u'ute_nr_pessoas_cargo',
#        u'ute_nr_descendentes_cargo', u'candidatura_data_ppe', u'user_count'],
#       dtype='object')

# %%
plt.hist(results_df['candidatura_prof_pret_tempo_pratica'].dropna(), bins=10, alpha=0.5)
plt.hist(results_df['sit_anterior_prof_tempo_pratica'].dropna(), bins=10,alpha=0.3)
# Out:
# (array([  8.31070000e+04,   1.63680000e+04,   7.09300000e+03,
#           3.31800000e+03,   1.47300000e+03,   2.12000000e+02,
#           1.70000000e+01,   1.00000000e+01,   0.00000000e+00,
#           3.00000000e+00]),
#  array([   0. ,   98.9,  197.8,  296.7,  395.6,  494.5,  593.4,  692.3,
#          791.2,  890.1,  989. ]),
#  <a list of 10 Patch objects>)

# %%
#plt.hist(results_df['candidatura_local_trabalho'].dropna())
#from collections import Counter
#results_df['candidatura_local_trabalho'].plot()

# %%
# local_trabalho_counts = DataFrame.from_dict(Counter(results_df['candidatura_local_trabalho']), orient='index')

# %%
# local_trabalho_counts.plot(kind='bar')

# %%
results_df.candidatura_local_trabalho.value_counts(dropna=False).plot(kind='bar')

# %%
def print_histograms (df):
    for x in df.columns:
        getattr(df,x).value_counts(dropna=False).plot(kind='bar')

# %%
#print_histograms(results_df.drop('ute_id', axis=1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-a12b9758d785> in <module>()
# ----> 1 print_histograms(results_df.drop('ute_id', axis=1))
#
# <ipython-input-23-1fd25a87a2da> in print_histograms(df)
#       1 def print_histograms (df):
#       2     for x in df.columns:
# ----> 3         getattr(df,x).value_counts(dropna=False).plot(kind='bar')
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2441                            colormap=colormap, table=table, yerr=yerr,
#    2442                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2443                            **kwds)
#    2444     __call__.__doc__ = plot_series.__doc__
#    2445
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1882                  yerr=yerr, xerr=xerr,
#    1883                  label=label, secondary_y=secondary_y,
# -> 1884                  **kwds)
#    1885
#    1886
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1682         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1683
# -> 1684     plot_obj.generate()
#    1685     plot_obj.draw()
#    1686     return plot_obj.result
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in generate(self)
#     238         self._compute_plot_data()
#     239         self._setup_subplots()
# --> 240         self._make_plot()
#     241         self._add_table()
#     242         self._make_legend()
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _make_plot(self)
#    1211                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
#    1212                                   start=start, label=label,
# -> 1213                                   log=self.log, **kwds)
#    1214             self._add_legend_handle(rect, label, index=i)
#    1215
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1158     @classmethod
#    1159     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1160         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1161
#    1162     @property
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    2126             elif orientation == 'horizontal':
#    2127                 r.sticky_edges.x.append(l)
# -> 2128             self.add_patch(r)
#    2129             patches.append(r)
#    2130
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_patch(self, p)
#    1866         if p.get_clip_path() is None:
#    1867             p.set_clip_path(self.patch)
# -> 1868         self._update_patch_limits(p)
#    1869         self.patches.append(p)
#    1870         p._remove_method = lambda h: self.patches.remove(h)
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _update_patch_limits(self, patch)
#    1886         vertices = patch.get_path().vertices
#    1887         if vertices.size > 0:
# -> 1888             xys = patch.get_patch_transform().transform(vertices)
#    1889             if patch.get_data_transform() != self.transData:
#    1890                 patch_to_data = (patch.get_data_transform() -
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in get_patch_transform(self)
#     719
#     720     def get_patch_transform(self):
# --> 721         self._update_patch_transform()
#     722         return self._rect_transform
#     723
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in _update_patch_transform(self)
#     713         height = self.convert_yunits(self._height)
#     714         bbox = transforms.Bbox.from_bounds(x, y, width, height)
# --> 715         rot_trans = transforms.Affine2D()
#     716         rot_trans.rotate_deg_around(x, y, self._angle)
#     717         self._rect_transform = transforms.BboxTransformTo(bbox)
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in __init__(self, matrix, **kwargs)
#    1822             matrix = np.asarray(matrix, np.float_)
#    1823             assert matrix.shape == (3, 3)
# -> 1824         self._mtx = matrix
#    1825         self._invalid = 0
#    1826
#
# KeyboardInterrupt:

# %%
print_histograms(results_df[['anomes','candidatura_rinsc']])
