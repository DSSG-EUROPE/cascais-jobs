# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import psycopg2 as pg
# %matplotlib inline
import seaborn as sns
import dbcreds

# %%
conn = pg.connect(dbname = dbcreds.database, host=dbcreds.host, user=dbcreds.user, password = dbcreds.password)

# %%
def generate_df(schema, table_list, conn):
    df_dict = {}
    for table in table_list:
        df_dict[table] = pd.read_sql('select * from '+schema+'.'+table, con=conn)
    return df_dict

# %%
# read all csvs and return as dataframes

df_dict = generate_df('IEFP',['applications','cancellations','category_changes','convocations','interventions','interviews'], conn)

# %%
# name dataframes

apps_df = df_dict['applications']
cancel_df = df_dict['cancellations']
cat_changes_df = df_dict['category_changes']
conv_df = df_dict['convocations']
interventions_df = df_dict['interventions']
interviews_df = df_dict['interviews']

# %%
# create year and month
apps_df['year'] = apps_df['anomes'].apply(lambda x: int(str(x)[0:4]))
apps_df['month'] = apps_df['anomes'].apply(lambda x: int(str(x)[4:6]))
cancel_df['year'] = cancel_df['anulacao_data'].apply(lambda x: None if x is None else int(x[0:4]))
cancel_df['month'] = cancel_df['anulacao_data'].apply(lambda x: None if x is None else int(x[5:7]))
interviews_df['year'] = interviews_df['anomes'].apply(lambda x: int(str(x)[0:4]))
interviews_df['month'] = interviews_df['anomes'].apply(lambda x: int(str(x)[4:6]))

#create convocation type + result
conv_df['type_result']=conv_df['dtipo_convocatoria']+'_'+conv_df['dresultado_convocatoria']

# map category changes codes to description
cat_translation = {1.0: 'Unemployed - 1st job', 2.0: 'Unemployed - new job',
                  3: 'Employed', 4: 'Part-time employed', 5: 'Busy',
                  6: 'Unavailable - 1st job', 7: 'Unavailable - new job',
                  8: 'Unavailable - employed'}
cat_changes_df['previous_cat_int'] = cat_changes_df['candidatura_categoria_anterior'].apply(lambda x: float(x) if pd.notnull(x) else None)
cat_changes_df['previous_cat'] = cat_changes_df['previous_cat_int'].apply(lambda x: cat_translation[x] if pd.notnull(x) else np.nan)
cat_changes_df['new_cat'] = cat_changes_df['ccategoria'].apply(lambda x: cat_translation[x] if pd.notnull(x) else np.nan)

# %%
#see column names
#apps_df.columns
type(cat_changes_df.candidatura_categoria_anterior[118000])
#type(cat_changes_df.ccategoria[0])
#cat_changes_df.tail(100)
# Out:
# str

# %%
# number of unique people per year
#DataFrame(apps_df.groupby(['year','dcategoria']).ute_id.nunique())
#DataFrame(apps_df.groupby(['year','month']).ute_id.nunique().unstack())

# %%
# first applications, grouped by "The application is a re-registration"
# apps_df.drop_duplicates('ute_id',keep='first').groupby('candidatura_rinsc').ute_id.count()

# %%
# rename some variables
cancel_df.rename(columns={'id':'ute_id'}, inplace=True)

# %%
# print num records and num unique IDs for each DF
def summary_stats(df):
    num_records = len(df)
    num_unique = df.ute_id.nunique()
    return num_records, num_unique
summary_stats(conv_df)
# Out:
# (256327, 59170)

# %%
#cancel_df[cancel_df['ute_id'].isin(apps_df['ute_id'])]
#conv_df.columns

# %%
apps_df.groupby('dhabilitacao_escolar').ute_id.count().plot(kind='bar')

# %%
apps_df[apps_df['dhabilitacao_escolar']=='LICENCIATURA'].groupby('ute_idade').ute_id.count().plot(kind='bar', figsize = (15,6))

# %%
age_licenciatura = DataFrame(apps_df[apps_df['dhabilitacao_escolar']=='11 ANOS'].groupby(['ute_idade', 'year']).ute_id.count())
age_licenciatura = age_licenciatura.reset_index().pivot( "ute_idade", "year","ute_id").sort_index(ascending=False)
#edu_age = edu_age.reindex(index = ["65+", "50-64","30-49","<30"], columns = edu_order)
#edu_age = edu_age.fillna(value = 0)

fig, ax = plt.subplots(figsize = (20,15))
sns.heatmap(age_licenciatura, annot=True, fmt='g', ax=ax)
plt.title("\nNumber of applicants by age and year")

# %%
apps_df[apps_df['dhabilitacao_escolar']=='11 ANOS'].groupby('ute_idade').ute_id.count().plot(kind='bar', figsize = (15,6))

# %%
apps_df['year']=apps_df.loc[:, 'anomes'].apply(lambda x: int(str(x)[0:4]))
apps_df[apps_df['year']==2015].groupby('ute_idade').dhabilitacao_escolar.value_counts().unstack()
# Out:
# dhabilitacao_escolar  11 ANOS  12 ANOS  4 ANOS  6 ANOS  9 ANOS  BACHARELATO  \
# ute_idade
# 15                        NaN      NaN     1.0     NaN     1.0          NaN
# 16                        NaN      NaN     2.0     3.0    12.0          NaN
# 17                        1.0      NaN     2.0     2.0    29.0          NaN
# 18                       15.0     60.0     5.0    52.0   115.0          NaN
# 19                       13.0     92.0     2.0    38.0   140.0          NaN
# 20                       18.0    134.0     9.0    38.0   117.0          NaN
# 21                       18.0    137.0     3.0    43.0   124.0          NaN
# 22                       11.0    175.0     9.0    48.0    89.0          NaN
# 23                       15.0    176.0     4.0    31.0    73.0          NaN
# 24                       11.0    176.0     8.0    42.0    91.0          2.0
# 25                        9.0    179.0     7.0    39.0    66.0          NaN
# 26                       16.0    157.0    13.0    37.0    91.0          NaN
# 27                       14.0    116.0    10.0    33.0    69.0          NaN
# 28                        9.0    114.0    11.0    24.0    67.0          2.0
# 29                       12.0    111.0     7.0    26.0    65.0          NaN
# 30                       12.0    116.0     8.0    33.0    70.0          NaN
# 31                       13.0     92.0    18.0    29.0    61.0          NaN
# 32                       13.0    117.0    12.0    30.0    71.0          NaN
# 33                       11.0    109.0     7.0    36.0    43.0          1.0
# 34                        8.0    117.0    10.0    29.0    56.0          1.0
# 35                       16.0    115.0     8.0    30.0    63.0          4.0
# 36                       12.0    115.0    19.0    31.0    54.0          1.0
# 37                       15.0    105.0    15.0    38.0    61.0          3.0
# 38                       11.0    108.0    24.0    29.0    79.0          3.0
# 39                        7.0    100.0    16.0    47.0    62.0          4.0
# 40                       10.0     98.0    14.0    34.0    76.0         13.0
# 41                        8.0     93.0    20.0    36.0    50.0          6.0
# 42                        7.0     91.0    18.0    32.0    47.0          6.0
# 43                        9.0     88.0    16.0    39.0    68.0          2.0
# 44                        6.0    104.0    13.0    42.0    57.0          6.0
# 45                       10.0     81.0    22.0    43.0    59.0          1.0
# 46                       15.0     68.0    25.0    28.0    46.0         13.0
# 47                        8.0     64.0    24.0    48.0    55.0         12.0
# 48                       10.0     79.0    33.0    31.0    46.0          5.0
# 49                        8.0     81.0    24.0    34.0    56.0          2.0
# 50                       16.0     78.0    33.0    36.0    51.0          5.0
# 51                        7.0     59.0    34.0    24.0    44.0          7.0
# 52                        6.0     59.0    38.0    33.0    48.0          4.0
# 53                       10.0     70.0    38.0    25.0    51.0          2.0
# 54                       11.0     43.0    29.0    29.0    51.0          4.0
# 55                        8.0     65.0    40.0    24.0    51.0          6.0
# 56                       10.0     44.0    28.0    22.0    36.0          5.0
# 57                        9.0     45.0    35.0    25.0    34.0          4.0
# 58                        9.0     41.0    34.0    22.0    28.0          2.0
# 59                        8.0     23.0    42.0    22.0    33.0          2.0
# 60                        5.0     23.0    29.0    14.0    26.0          5.0
# 61                        4.0     23.0    45.0     9.0    29.0          2.0
# 62                        2.0     13.0    25.0    12.0    12.0          NaN
# 63                        2.0     23.0    22.0     9.0    17.0          2.0
# 64                        3.0     11.0    21.0    10.0    16.0          NaN
# 65                        1.0     10.0    15.0     4.0     5.0          1.0
# 66                        NaN      8.0     2.0     1.0     2.0          1.0
# 67                        NaN      1.0     3.0     1.0     NaN          NaN
# 68                        NaN      1.0     2.0     NaN     NaN          NaN
# 69                        NaN      2.0     1.0     NaN     NaN          NaN
# 70                        1.0      2.0     NaN     NaN     NaN          NaN
# 71                        NaN      1.0     1.0     NaN     NaN          NaN
#
# dhabilitacao_escolar  DOUTORAMENTO  ENSINO PÓS-SECUNDÁRIO  \
# ute_idade
# 15                             NaN                    NaN
# 16                             NaN                    NaN
# 17                             NaN                    NaN
# 18                             NaN                    NaN
# 19                             NaN                    NaN
# 20                             NaN                    NaN
# 21                             NaN                    2.0
# 22                             NaN                    NaN
# 23                             NaN                    1.0
# 24                             NaN                    2.0
# 25                             NaN                    2.0
# 26                             NaN                    2.0
# 27                             NaN                    3.0
# 28                             NaN                    NaN
# 29                             NaN                    NaN
# 30                             NaN                    3.0
# 31                             1.0                    NaN
# 32                             NaN                    NaN
# 33                             1.0                    NaN
# 34                             2.0                    NaN
# 35                             NaN                    1.0
# 36                             4.0                    NaN
# 37                             NaN                    NaN
# 38                             2.0                    2.0
# 39                             2.0                    NaN
# 40                             NaN                    NaN
# 41                             2.0                    1.0
# 42                             1.0                    NaN
# 43                             1.0                    NaN
# 44                             NaN                    2.0
# 45                             1.0                    NaN
# 46                             3.0                    NaN
# 47                             1.0                    NaN
# 48                             1.0                    NaN
# 49                             1.0                    NaN
# 50                             NaN                    NaN
# 51                             2.0                    1.0
# 52                             NaN                    1.0
# 53                             NaN                    NaN
# 54                             1.0                    NaN
# 55                             NaN                    NaN
# 56                             NaN                    NaN
# 57                             NaN                    NaN
# 58                             1.0                    2.0
# 59                             1.0                    NaN
# 60                             NaN                    NaN
# 61                             NaN                    NaN
# 62                             NaN                    NaN
# 63                             NaN                    NaN
# 64                             NaN                    NaN
# 65                             NaN                    NaN
# 66                             NaN                    NaN
# 67                             NaN                    NaN
# 68                             NaN                    NaN
# 69                             NaN                    NaN
# 70                             NaN                    NaN
# 71                             NaN                    NaN
#
# dhabilitacao_escolar  LER-ESCREVER S/GRAU ENSINO  LICENCIATURA  MESTRADO  \
# ute_idade
# 15                                           NaN           NaN       NaN
# 16                                           NaN           NaN       NaN
# 17                                           NaN           NaN       NaN
# 18                                           NaN           NaN       NaN
# 19                                           NaN           NaN       NaN
# 20                                           NaN           5.0       NaN
# 21                                           NaN          43.0       NaN
# 22                                           NaN          90.0       6.0
# 23                                           2.0         144.0      40.0
# 24                                           3.0         136.0      58.0
# 25                                           NaN         120.0      53.0
# 26                                           1.0          85.0      38.0
# 27                                           4.0         108.0      35.0
# 28                                           1.0          80.0      29.0
# 29                                           1.0          60.0      32.0
# 30                                           2.0          68.0      27.0
# 31                                           1.0          56.0      19.0
# 32                                           NaN          62.0       9.0
# 33                                           3.0          73.0       9.0
# 34                                           2.0          70.0      11.0
# 35                                           3.0          75.0       5.0
# 36                                           3.0          74.0      10.0
# 37                                           1.0          99.0       8.0
# 38                                           2.0          85.0       5.0
# 39                                           3.0          75.0       7.0
# 40                                           3.0          82.0       4.0
# 41                                           6.0          66.0       2.0
# 42                                           3.0          53.0       3.0
# 43                                           3.0          55.0       NaN
# 44                                           3.0          51.0       4.0
# 45                                           5.0          53.0       NaN
# 46                                          10.0          38.0       2.0
# 47                                           8.0          26.0       3.0
# 48                                           8.0          27.0       3.0
# 49                                           8.0          24.0       1.0
# 50                                           4.0          33.0       1.0
# 51                                           4.0          28.0       2.0
# 52                                           4.0          28.0       3.0
# 53                                           6.0          21.0       3.0
# 54                                           9.0          17.0       NaN
# 55                                          12.0           8.0       1.0
# 56                                           5.0          18.0       2.0
# 57                                           6.0          11.0       NaN
# 58                                           3.0          12.0       1.0
# 59                                           7.0          13.0       NaN
# 60                                           3.0          16.0       NaN
# 61                                           4.0           8.0       1.0
# 62                                           7.0           5.0       1.0
# 63                                           4.0           5.0       NaN
# 64                                           4.0           5.0       NaN
# 65                                           2.0           3.0       NaN
# 66                                           NaN           1.0       NaN
# 67                                           NaN           NaN       NaN
# 68                                           1.0           NaN       NaN
# 69                                           1.0           NaN       NaN
# 70                                           NaN           NaN       NaN
# 71                                           NaN           NaN       NaN
#
# dhabilitacao_escolar  NÃO SABE LER/ESCREVER
# ute_idade
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      1.0
# 21                                      NaN
# 22                                      1.0
# 23                                      2.0
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      1.0
# 28                                      1.0
# 29                                      2.0
# 30                                      3.0
# 31                                      2.0
# 32                                      3.0
# 33                                      2.0
# 34                                      2.0
# 35                                      1.0
# 36                                      4.0
# 37                                      4.0
# 38                                      4.0
# 39                                      1.0
# 40                                      2.0
# 41                                      NaN
# 42                                      NaN
# 43                                      1.0
# 44                                      1.0
# 45                                      NaN
# 46                                      6.0
# 47                                      3.0
# 48                                      5.0
# 49                                      8.0
# 50                                      4.0
# 51                                      5.0
# 52                                      8.0
# 53                                      2.0
# 54                                      7.0
# 55                                      8.0
# 56                                      4.0
# 57                                      3.0
# 58                                      4.0
# 59                                      4.0
# 60                                      3.0
# 61                                      3.0
# 62                                      5.0
# 63                                      8.0
# 64                                      4.0
# 65                                      2.0
# 66                                      1.0
# 67                                      1.0
# 68                                      NaN
# 69                                      NaN
# 70                                      NaN
# 71                                      NaN

# %%
interviews_df.head()
#len(conv_df[conv_df['dtipo_convocatoria']=='OFERTA'])
# Out:
#    anomes  ctipo_movimento            dtipo_movimento   ute_id  \
# 0  200701               37  RESULTADO APRESENTAÃÃES  1060922
# 1  200701               37  RESULTADO APRESENTAÃÃES  1062047
# 2  200701               37  RESULTADO APRESENTAÃÃES  1062047
# 3  200701               37  RESULTADO APRESENTAÃÃES  1080395
# 4  200701               37  RESULTADO APRESENTAÃÃES  1133828
#
#    apresentacao_resultado                            dresultado_apresentacao  \
# 0                      22  RECUSA DE ENTIDADE EMPREGADORA - DESAJUSTAMENT...
# 1                      10                                ADMITIDO / COLOCADO
# 2                      29         RECUSA ENTIDADE EMPREGADORA- OUTROSMOTIVOS
# 3                      10                                ADMITIDO / COLOCADO
# 4                      21  RECUSA DE ENTIDADE EMPREGADORA - POSTO JÃ PRE...
#
#    year  month
# 0  2007      1
# 1  2007      1
# 2  2007      1
# 3  2007      1
# 4  2007      1

# %%
users_apresentado = (conv_df[(conv_df['dtipo_convocatoria']=='OFERTA') & (conv_df['dresultado_convocatoria']=='APRESENTADO')])

# %%
DataFrame(conv_df[conv_df['dtipo_convocatoria']=='OFERTA'].groupby('dresultado_convocatoria').ute_id.count().sort_values(ascending=False))
# Out:
#                                                     ute_id
# dresultado_convocatoria
# APRESENTADO                                          41781
# NÃO APRESENTADO                                     12217
# NÃO COMPARECEU INJUSTIFICADAMENTE                    4010
# ANULADA                                               1517
# NÃO COMPARECEU JUSTIFICADAMENTE                       293
# NÃO COMPARECEU JUSTIFICADAMENTE - RESPOSTA AUT...      68
# RECUSA INJUSTIFICADA - PROFISSÃO OFERECIDA             61
# RECUSA JUSTIFICADA - PROFISSÃO OFERECIDA               25
# RECUSA INJUSTIFICADA - OUTRAS RAZÃES                   12
# RECUSA INJUSTIFICADA - RAZÃES SALARIAIS                 5
# RECUSA JUSTIFICADA - OUTRAS RAZÃES                      2
# RECUSA INJUSTIFICADA - DISTÃNCIA/TEMPO                  2
# RECUSOU                                                  1
# RECUSA JUSTIFICADA - RAZÃES SALARIAIS                   1

# %% [markdown]
# # Overview histograms for each data source

# %%
# exploratory histograms
# define function to print multiple histograms
def print_histograms (df):
    for x in df.columns:
        plt.figure()
        getattr(df,x).value_counts(dropna=False).plot(kind='bar', title=x, figsize = (10,3))

# %%
#print_histograms(cancel_df[['dmotivo_anulacao']])

#apps_df.dhabilitacao_escolar.value_counts().plot(kind='bar', figsize = (3,2), title="Top Years of Schooling")
male_dependents = DataFrame(apps_df[apps_df['sexo']=='M'].ute_nr_pessoas_cargo.value_counts()).rename(columns={'ute_nr_pessoas_cargo':'male_applicants'}) #.plot(kind='bar',xlim=(0,20), color='green')
female_dependents = DataFrame(apps_df[apps_df['sexo']=='F'].ute_nr_pessoas_cargo.value_counts()).rename(columns={'ute_nr_pessoas_cargo':'female_applicants'}) #.plot(kind='bar',xlim=(0,20),color='blue')
pd.concat([male_dependents,female_dependents],axis=1).plot(kind='bar', figsize=(5,3), title='Number of dependents')

#conv_df.dtipo_convocatoria.value_counts().sort_values().plot(
#    kind='barh', title="Top types of convocations \n", figsize = (3,5)).tick_params(labeltop='on', labelbottom='off')
#DataFrame(conv_df.groupby('dtipo_convocatoria').ute_id.count().sort_values(ascending=False))

#conv_df.dresultado_convocatoria.value_counts().sort_values().plot(
#    kind='barh', title="Top results of convocations \n", figsize = (3,5)).tick_params(labeltop='on', labelbottom='off')
#DataFrame(conv_df.groupby('dresultado_convocatoria').ute_id.count().sort_values(ascending=False))

#interviews_df.dresultado_apresentacao.value_counts().sort_values().plot(
#    kind='barh' ,title="top results of interviews\n", figsize = (3,5)).tick_params(labeltop='on', labelbottom='off')
#DataFrame(interviews_df.groupby('dresultado_apresentacao').ute_id.count().sort_values(ascending=False))

#interventions_df.intervencao_codigo_d.value_counts().sort_values(ascending=False)[0:5].plot(
#    kind='bar', title="top interventions\n", figsize = (5,3), rot=80, fontsize=11)
#DataFrame(interventions_df.groupby('intervencao_codigo_d').ute_id.count().sort_values(ascending=False))

#cancel_df.dmotivo_anulacao.value_counts().sort_values().plot(
#    kind='barh', title="top reasons for cancellations\n", figsize = (3,10)).tick_params(labeltop='on', labelbottom='off')
#DataFrame(cancel_df.groupby('dmotivo_anulacao').ute_id.count().sort_values(ascending=False))
# Out:
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#
#DataFrame(cat_changes_df.groupby(['previous_cat','new_cat']).ute_id.count().sort_values(ascending=False))

# %% [markdown]
# # Additional overview visualizations

# %%
#plot number of interviews and % that were placements
all_int = DataFrame(interviews_df.groupby('year').ute_id.count()).rename(columns={'ute_id':'interviews'}) #.plot(kind='bar', fontsize=16, figsize=(5,4), title="Number of interviews by year")
placements = DataFrame(interviews_df[interviews_df['dresultado_apresentacao']=='ADMITIDO / COLOCADO'].groupby('year').ute_id.count()).rename(columns={'ute_id':'placements'}) #.plot(kind='bar', fontsize=16, figsize=(5,4), title="Number of placements by year")
int_placements = pd.concat([all_int,placements],axis=1)
int_placements['percent_placements'] = int_placements['placements']/int_placements['interviews']*100

int_placements.percent_placements.plot(marker = 'o', style='green', title = 'Interviews and placements', legend = True, ylim = (0,13))
int_placements.interviews.plot(marker = 'o',style = 'blue', secondary_y=True, legend=True, ylim = (0,13))

# %% [markdown]
# # Outcome labeling

# %%
# Count applications between 2007-2015
app_range = apps_df[apps_df['year'].apply(lambda x: x in range(2007,2016))]
len(app_range)
# Out:
# 108845

# %%
#user IDs in interviews that are not in applications
#interviews_df[interviews_df['ute_id'].apply(lambda x: x not in apps_df['ute_id'])].ute_id.sort_values().unique()
cancel_df.head()
# Out:
#    anomes  ctipo_movimento               dtipo_movimento   ute_id  \
# 0  200701               31  ANULAÃÃES AO LONGO DO MÃS  1068894
# 1  200701               31  ANULAÃÃES AO LONGO DO MÃS  1100731
# 2  200701               31  ANULAÃÃES AO LONGO DO MÃS  1183200
# 3  200701               31  ANULAÃÃES AO LONGO DO MÃS  1218220
# 4  200701               31  ANULAÃÃES AO LONGO DO MÃS  1263911
#
#    anulacao_motivo                                   dmotivo_anulacao  \
# 0               20  COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA DE ...
# 1               14                            RECUSA DE INTERVENÃÃO
# 2               11                              FALTA A CONVOCATÃRIA
# 3               12                                  FALTA AO CONTROLO
# 4               20  COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA DE ...
#
#          anulacao_data    year  month
# 0  2007-01-25 00:00:00  2007.0    1.0
# 1                 None     NaN    NaN
# 2  2007-01-30 11:12:23  2007.0    1.0
# 3  2007-01-30 00:00:00  2007.0    1.0
# 4  2007-01-02 00:00:00  2007.0    1.0

# %%
#Found job through IEFP
IEFP_placements = interviews_df[(interviews_df['ute_id'].isin(app_range['ute_id']))&(interviews_df['apresentacao_resultado']==10)]
len(IEFP_placements)
# Out:
# 7462

# %%
cancel_df['dmotivo_anulacao'].value_counts()
# Out:
# FALTA AO CONTROLO                                                                            34670
# FALTA A CONVOCATÃRIA                                                                        33775
# COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA DE OUTREM                                         23868
# EMIGRAÃÃO, AUSÃNCIA DO PAÃS                                                               4839
# TRANSFERÃNCIA DE CENTRO DE EMPREGO                                                           3272
# REFORMOU-SE                                                                                   2457
# FREQUÃNCIA DE FORMAÃÃO DO IEFP (ENTRADA SGFOR)                                             1885
# COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA PRÃPRIA                                           1293
# INSERÃÃO NOUTROS PROGRAMAS/MEDIDAS EMPREGO (SIEF)                                           1071
# DESISTIU                                                                                      1062
# OUTROS MOTIVOS                                                                                 950
# INCUMPRIMENTO DA APRESENTAÃÃO QUINZENAL                                                      831
# RECUSA DE INTERVENÃÃO                                                                        640
# INSERÃÃO POR CONTA OUTRÃM, NA SEQUÃNCIA DE PROGRAMA                                        565
# CRIAÃÃO DO PRÃPRIO EMPREGO                                                                  532
# RECUSA DE FORMAÃÃO PROFISSIONAL                                                              454
# FREQUÃNCIA DE CURSO DE FORMAÃÃO PROFISSIONAL DO IEFP                                        363
# FALTA Ã APRESENTAÃÃO                                                                        319
# FREQUÃNCIA DE FORMAÃÃO EM ENTIDADE EXTERNA AO IEFP                                          293
# INCAPACIDADE PROLONGADA / PERMANENTE PARA O TRABALHO                                           290
# RECUSA DE EMPREGO CONVENIENTE                                                                  208
# CADUCIDADE DO DOCUMENTO DE IDENTIFICAÃÃO                                                     186
# FALECIMENTO                                                                                    113
# TRANSFERÃNCIA REGIÃES AUTÃNOMAS                                                              74
# DESISTÃNCIA OU EXCLUSÃO DE FORMAÃÃO                                                         62
# REINÃCIO DE ESTUDOS                                                                            53
# DESISTÃNCIA OU EXCLUSÃO DE TRABALHO SOCIALMENTE NECESSÃRIO                                   28
# RECUSA DE TRABALHO SOCIALMENTE NECESSÃRIO                                                      26
# DETENÃÃO EM ESTABELECIMENTO PRISIONAL                                                         17
# FREQUÃNCIA DE ESTÃGIO PROFISSIONAL PEPAP                                                      10
# INÃCIO DE LICENÃA DE MATERNIDADE, PATERNIDADE OU ADOPÃÃO                                    10
# EXERCÃCIO ATIVIDADE PROFISSIONAL COMO MOE                                                       9
# FREQUÃNCIA DE ESTÃGIO PROFISSIONAL PEPAL                                                       8
# DESISTÃNCIA OU EXCLUSÃO DE MEDIDAS DE EMPREGO (EXCLUI TRABALHO SOCIALMENTE NECESSÃRIO)        6
# COLOCAÃÃO - CANDIDATURA EXTERNA                                                                5
# CUMPRIMENTO SERVIÃO MILITAR                                                                     3
# CORRECÃÃO COLOCAÃÃO FME                                                                      3
# FREQUÃNCIA DE ESTÃGIO PROFISSIONAL PEPAC                                                       2
# CORRECÃÃO REINSCRIÃÃO FME                                                                    2
# RECUSA DE FORMALIZAÃÃO DE PPE                                                                  2
# INSCRIÃÃO CANDIDATURA EXTERNA                                                                  2
# COLOCAÃÃO - CANDIDATURA INTERNA                                                                1
# TERMO DA PROCURA ACTIVA EMPREGO EM PT                                                            1
# INCUMPRIMENTO DO DEVER DE PAE                                                                    1
# Name: dmotivo_anulacao, dtype: int64

# %%
#Found job in another way
outside_placements = cancel_df[(cancel_df['ute_id'].isin(
    app_range['ute_id']))&(cancel_df['dmotivo_anulacao'].isin(
    ['CRIAÃÃO DO PRÃPRIO EMPREGO', 'COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA DE OUTREM','COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA PRÃPRIA', 'COLOCAÃÃO - CANDIDATURA EXTERNA']))]
len(outside_placements)
# Out:
# 24320

# %%
interviews_df[['year','month']].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-4afa2c905ffc> in <module>()
# ----> 1 interviews_df[['year','month']].plot(kind='bar')
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2615                           fontsize=fontsize, colormap=colormap, table=table,
#    2616                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2617                           sort_columns=sort_columns, **kwds)
#    2618     __call__.__doc__ = plot_frame.__doc__
#    2619
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1857                  yerr=yerr, xerr=xerr,
#    1858                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1859                  **kwds)
#    1860
#    1861
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1682         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1683
# -> 1684     plot_obj.generate()
#    1685     plot_obj.draw()
#    1686     return plot_obj.result
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in generate(self)
#     238         self._compute_plot_data()
#     239         self._setup_subplots()
# --> 240         self._make_plot()
#     241         self._add_table()
#     242         self._make_legend()
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _make_plot(self)
#    1211                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
#    1212                                   start=start, label=label,
# -> 1213                                   log=self.log, **kwds)
#    1214             self._add_legend_handle(rect, label, index=i)
#    1215
#
# /opt/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1158     @classmethod
#    1159     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1160         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1161
#    1162     @property
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    2126             elif orientation == 'horizontal':
#    2127                 r.sticky_edges.x.append(l)
# -> 2128             self.add_patch(r)
#    2129             patches.append(r)
#    2130
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_patch(self, p)
#    1866         if p.get_clip_path() is None:
#    1867             p.set_clip_path(self.patch)
# -> 1868         self._update_patch_limits(p)
#    1869         self.patches.append(p)
#    1870         p._remove_method = lambda h: self.patches.remove(h)
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _update_patch_limits(self, patch)
#    1892                 xys = patch_to_data.transform(xys)
#    1893
# -> 1894             updatex, updatey = patch.get_transform().\
#    1895                 contains_branch_seperately(self.transData)
#    1896             self.update_datalim(xys, updatex=updatex,
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in get_transform(self)
#     219         to the :class:`Patch`.
#     220         """
# --> 221         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     222
#     223     def get_data_transform(self):
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in get_patch_transform(self)
#     719
#     720     def get_patch_transform(self):
# --> 721         self._update_patch_transform()
#     722         return self._rect_transform
#     723
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in _update_patch_transform(self)
#     714         bbox = transforms.Bbox.from_bounds(x, y, width, height)
#     715         rot_trans = transforms.Affine2D()
# --> 716         rot_trans.rotate_deg_around(x, y, self._angle)
#     717         self._rect_transform = transforms.BboxTransformTo(bbox)
#     718         self._rect_transform += rot_trans
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in rotate_deg_around(self, x, y, degrees)
#    1953         and :meth:`scale`.
#    1954         """
# -> 1955         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1956
#    1957     def translate(self, tx, ty):
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in rotate_deg(self, degrees)
#    1933         and :meth:`scale`.
#    1934         """
# -> 1935         return self.rotate(degrees * np.pi / 180.)
#    1936
#    1937     def rotate_around(self, x, y, theta):
#
# /opt/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in rotate(self, theta)
#    1916         and :meth:`scale`.
#    1917         """
# -> 1918         a = np.cos(theta)
#    1919         b = np.sin(theta)
#    1920         rotate_mtx = np.array(
#
# KeyboardInterrupt:

# %%
apps_df.describe()
# Out:
#               anomes  ctipo_movimento        ute_id   cdeficiencia  \
# count  125029.000000         125029.0  1.250290e+05  125029.000000
# mean   201193.832015             11.0  3.657269e+06       1.139376
# std       290.677615              0.0  1.572727e+06       8.635790
# min    200701.000000             11.0  7.100000e+02       0.000000
# 25%    200911.000000             11.0  2.451257e+06       0.000000
# 50%    201206.000000             11.0  3.909178e+06       0.000000
# 75%    201411.000000             11.0  4.756382e+06       0.000000
# max    201704.000000             11.0  6.550048e+06      99.000000
#
#        cnp_pretendida  cpp_pretendida     ccategoria  \
# count   111702.000000    42412.000000  125029.000000
# mean    534564.843369    51928.425964       1.940478
# std     236583.620475    25032.567888       0.394164
# min        315.000000       13.000000       1.000000
# 25%     342210.000000    32560.000000       2.000000
# 50%     512320.000000    51320.000000       2.000000
# 75%     714105.000000    71311.000000       2.000000
# max     999999.000000    96292.000000       4.000000
#
#        candidatura_motivo_inscricao  candidatura_int_tempo_nao_insc  \
# count                 125029.000000                    78703.000000
# mean                       9.060770                       21.983355
# std                       10.698637                       29.131316
# min                        1.000000                        0.000000
# 25%                        6.000000                        3.000000
# 50%                        8.000000                       10.000000
# 75%                        8.000000                       29.000000
# max                       99.000000                      191.000000
#
#        candidatura_prof_pret_tempo_pratica      ...        \
# count                        113451.000000      ...
# mean                             72.501996      ...
# std                              94.068923      ...
# min                               0.000000      ...
# 25%                              11.000000      ...
# 50%                              36.000000      ...
# 75%                             100.000000      ...
# max                             989.000000      ...
#
#        ute_curso_ano_conclusão   cae_anterior      ute_idade  \
# count             22613.000000  110729.000000  125029.000000
# mean               2000.379339   42684.005644      36.448896
# std                  81.616173   31747.385921      12.080153
# min                   0.000000       0.000000      14.000000
# 25%                1999.000000    9609.000000      26.000000
# 50%                2006.000000   47111.000000      35.000000
# 75%                2010.000000   73110.000000      45.000000
# max                2017.000000   99000.000000      99.000000
#
#        conjuge_categoria  conjuge_motivo_indisponibilidade  \
# count        1246.000000                         24.000000
# mean            2.301766                          1.791667
# std             1.010998                          0.883627
# min             1.000000                          1.000000
# 25%             2.000000                          1.000000
# 50%             2.000000                          1.500000
# 75%             2.000000                          3.000000
# max             7.000000                          3.000000
#
#        candidatura_categoria_anterior  ute_nr_pessoas_cargo  \
# count                    49751.000000          73390.000000
# mean                         2.037346              1.212100
# std                          0.515384              3.705312
# min                          1.000000              0.000000
# 25%                          2.000000              0.000000
# 50%                          2.000000              1.000000
# 75%                          2.000000              2.000000
# max                          5.000000             99.000000
#
#        ute_nr_descendentes_cargo           year          month
# count               63239.000000  125029.000000  125029.000000
# mean                    0.817771    2011.876197       6.212343
# std                     3.951743       2.908707       3.508687
# min                     0.000000    2007.000000       1.000000
# 25%                     0.000000    2009.000000       3.000000
# 50%                     0.000000    2012.000000       6.000000
# 75%                     1.000000    2014.000000       9.000000
# max                    99.000000    2017.000000      12.000000
#
# [8 rows x 27 columns]

# %%
conv_df.head[conv_df['convocatoria_resultado']==10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9f156a7d3d76> in <module>()
# ----> 1 conv_df.head[conv_df['convocatoria_resultado']==10]
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
#conv_df.groupby(['dtipo_convocatoria','dresultado_convocatoria']).ute_id.count()

# %%
#find count of variable options
DataFrame(interviews_df.groupby('dresultado_apresentacao').ute_id.count().sort_values(ascending=False).apply(lambda x: x*100/len(interviews_df)))

# %%
# list of unique IDs
users_list = apps_df.drop_duplicates('ute_id',keep='first')['ute_id']
cancel_users_list = cancel_df.drop_duplicates('ute_id',keep='first')['ute_id']
cat_changes_users_list = cat_changes_df.drop_duplicates('ute_id',keep='first')['ute_id']
conv_users_list = conv_df.drop_duplicates('ute_id',keep='first')['ute_id']
interventions_users_list = interventions_df.drop_duplicates('ute_id',keep='first')['ute_id']
interviews_users_list = interviews_df.drop_duplicates('ute_id',keep='first')['ute_id']

len(users_list)
# Out:
# 65523

# %%
# create dataframe with one row per user that submitted an application
users_df = DataFrame(users_list)

# %%
users_df['cancellations'] = users_df['ute_id'].apply(lambda x: x in cancel_users_list)
users_df['convocations'] = users_df['ute_id'].apply(lambda x: x in conv_users_list)
users_df['cat_changes'] = users_df['ute_id'].apply(lambda x: x in cat_changes_users_list)
users_df['interventions'] = users_df['ute_id'].apply(lambda x: x in interventions_users_list)

# %%
user_counts = DataFrame(apps_df.ute_id.value_counts())
user_counts_cancel = cancel_df.ute_id.value_counts()

# %%
user_counts['cancellations'] = user_counts.index
user_counts.head()
# Out:
#          ute_id  cancellations
# 2334945      35        2334945
# 5745193      30        5745193
# 2981696      20        2981696
# 3672353      18        3672353
# 2433439      17        2433439

# %%
#user_counts['cancellations']=user_counts_cancel[user_counts['cancellations']]

# %%
cancel_df.head()
# Out:
#    anomes  ctipo_movimento               dtipo_movimento   ute_id  \
# 0  200701               31  ANULAÃÃES AO LONGO DO MÃS  1068894
# 1  200701               31  ANULAÃÃES AO LONGO DO MÃS  1100731
# 2  200701               31  ANULAÃÃES AO LONGO DO MÃS  1183200
# 3  200701               31  ANULAÃÃES AO LONGO DO MÃS  1218220
# 4  200701               31  ANULAÃÃES AO LONGO DO MÃS  1263911
#
#    anulacao_motivo                                   dmotivo_anulacao  \
# 0               20  COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA DE ...
# 1               14                            RECUSA DE INTERVENÃÃO
# 2               11                              FALTA A CONVOCATÃRIA
# 3               12                                  FALTA AO CONTROLO
# 4               20  COLOCAÃÃO POR MEIOS PRÃPRIOS, POR CONTA DE ...
#
#          anulacao_data
# 0  2007-01-25 00:00:00
# 1                 None
# 2  2007-01-30 11:12:23
# 3  2007-01-30 00:00:00
# 4  2007-01-02 00:00:00

# %%
type(user_counts_cancel)
# Out:
# pandas.core.series.Series

# %%
user_counts_cancel[[3672353, 3672353]]
# Out:
# 3672353    16
# 3672353    16
# Name: ute_id, dtype: int64
